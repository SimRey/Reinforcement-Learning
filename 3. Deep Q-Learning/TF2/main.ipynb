# %%
from dqn_agent import Agent as DQN_Agent
from ddqn_agent import Agent as DDQN_Agent
import numpy as np
import gym
import matplotlib.pyplot as plt
from IPython.display import clear_output
import tensorflow.keras as keras

# %%
if __name__ == '__main__':
    env = gym.make('CartPole-v0')
    best_score = -np.inf
    n_games = 301
    agent = DQN_Agent(gamma=0.99, epsilon=1., lr=0.001, input_dims=(env.observation_space.shape), 
                  n_actions=env.action_space.n, mem_size=50000, eps_min=0.01, batch_size=32, replace=100,
                  eps_dec=1e-4)
    
    scores, eps_history = [], []

    for i in range(n_games):
        done = False
        observation = env.reset()

        score = 0
        while not done:
            action = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            score += reward
            agent.store_transition(observation, action, reward, observation_, done)
            agent.learn()

            observation = observation_
        
        scores.append(score)

        avg_score = np.mean(scores[-100:])
        clear_output(wait=True)

        if score > best_score:
            best_score = score

        eps_history.append(agent.epsilon)

        print(f"episode: {i}, score: {score:.1f}, avg score {avg_score:.1f}, best score: {best_score:.1f}, epsilon: {agent.epsilon:.2f}")
    
    agent.save_model()
# Out:
# episode: 300, score: 199.0, avg score 175.8, best score: 200.0, epsilon: 0.01

# %%
x = [i+1 for i in range(n_games)]
    
fig=plt.figure()
ax=fig.add_subplot(111, label="1")
ax2=fig.add_subplot(111, label="2", frame_on=False)

ax.plot(x, eps_history, color="C0")
ax.set_xlabel("Training Steps", color="C0")
ax.set_ylabel("Epsilon", color="C0")
ax.tick_params(axis='x', colors="C0")
ax.tick_params(axis='y', colors="C0")

N = len(scores)
running_avg = np.empty(N)
for t in range(N):
    running_avg[t] = np.mean(scores[max(0, t-20):(t+1)])

ax2.scatter(x, running_avg, color="C1")
ax2.axes.get_xaxis()
ax2.yaxis.tick_right()
ax2.set_ylabel('Score', color="C1")
ax2.yaxis.set_label_position('right')
ax2.tick_params(axis='y', colors="C1")

# %%
obs = env.reset()
points = 0
actions = []
 
model = keras.models.load_model(agent.model_file)
 
 
def test(model, obs, env):
    # Get discretized observation
    obs = np.reshape(obs, [1, agent.input_dims[0]])
    action = np.argmax(agent.model.predict(obs))
 
    # Perform the action
    obs, reward, done, *info = env.step(action) # Finally perform the action
 
    return obs, action, reward, done, *info
 
for counter in range(200):
    env.render(mode="human")
    points += 1
 
    obs, action, reward, done, *info = test(model, obs, env)
 
    actions.append(action)
    if done:
        print(f"Done, points: {points}")
        break
 
env.close()
# Out:
# ...
# 1/1 [==============================] - 0s 34ms/step
# Done, points: 145

# %%
if __name__ == '__main__':
    env = gym.make('CartPole-v0') 
    best_score = -np.inf
    n_games = 301
    agent2 =  DDQN_Agent(gamma=0.99, epsilon=1., lr=0.001, input_dims=(env.observation_space.shape), 
                  n_actions=env.action_space.n, mem_size=50000, eps_min=0.01, batch_size=32,
                  replace=100, eps_dec=1e-4, fname="ddqn.h5")
  
    scores, eps_history = [], []

    for i in range(n_games):
        done = False
        observation = env.reset()

        score = 0
        while not done:
            action = agent2.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            score += reward
            agent2.store_transition(observation, action, reward, observation_, done)
            agent2.learn()

            observation = observation_
        
        scores.append(score)

        avg_score = np.mean(scores[-100:])
        clear_output(wait=True)

        if score > best_score:
            best_score = score

        eps_history.append(agent2.epsilon)

        print(f"episode: {i}, score: {score:.1f}, avg score {avg_score:.1f}, best score: {best_score:.1f}, epsilon: {agent2.epsilon:.2f}")
    agent2.save_model()
# Out:
# episode: 300, score: 200.0, avg score 163.6, best score: 200.0, epsilon: 0.01

# %%
x = [i+1 for i in range(n_games)]
    
fig=plt.figure()
ax=fig.add_subplot(111, label="1")
ax2=fig.add_subplot(111, label="2", frame_on=False)

ax.plot(x, eps_history, color="C0")
ax.set_xlabel("Training Steps", color="C0")
ax.set_ylabel("Epsilon", color="C0")
ax.tick_params(axis='x', colors="C0")
ax.tick_params(axis='y', colors="C0")

N = len(scores)
running_avg = np.empty(N)
for t in range(N):
    running_avg[t] = np.mean(scores[max(0, t-20):(t+1)])

ax2.scatter(x, running_avg, color="C1")
ax2.axes.get_xaxis()
ax2.yaxis.tick_right()
ax2.set_ylabel('Score', color="C1")
ax2.yaxis.set_label_position('right')
ax2.tick_params(axis='y', colors="C1")

# %%
obs = env.reset()
env.render(mode='human')
points = 0
actions = []
 
model = keras.models.load_model(agent2.model_file)
 
 
def test(model, obs, env):
    # Get discretized observation
    obs = np.reshape(obs, [1, agent2.input_dims[0]])
    action = np.argmax(agent2.model.predict(obs))
 
    # Perform the action
    obs, reward, done, *info = env.step(action) # Finally perform the action
 
    return obs, action, reward, done, *info
 
for counter in range(200):
    env.render(mode="human")
    points += 1
 
    obs, action, reward, done, *info = test(model, obs, env)
 
    actions.append(action)
    if done:
        print(f"Done, points: {points}")
        break
 
env.close()
# Out:
# ...
# 1/1 [==============================] - 0s 31ms/step
# Done, points: 200
