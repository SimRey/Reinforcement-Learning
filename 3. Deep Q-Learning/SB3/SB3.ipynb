# %% [markdown]
# ## <center>Stable baslines 3</center>

# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import DQN
from stable_baselines3.common import results_plotter
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), 'timesteps')
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose > 0:
                print(f"Num timesteps: {self.num_timesteps}")
                print(f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}")

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose > 0:
                    print(f"Saving new best model to {self.save_path}.zip")
                  self.model.save(self.save_path)

        return True

# %%
# Create and wrap the environment

# Create log dir
log_dir = "C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/SB3/tmp/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = gym.make("CartPole-v0")
# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)

# %%
# Create and train the agent

# Create the callback: check every 1000 steps
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)
# Create RL model
model = DQN("MlpPolicy", env)

# Train the agent
model.learn(total_timesteps=int(200000), callback=callback)
# Out:
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: 21.28
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 2000
# Best mean reward: 21.28 - Last mean reward per episode: 22.42
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 3000
# Best mean reward: 22.42 - Last mean reward per episode: 24.10
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 4000
# Best mean reward: 24.10 - Last mean reward per episode: 26.58
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 5000
# Best mean reward: 26.58 - Last mean reward per episode: 25.73
# Num timesteps: 6000
# Best mean reward: 26.58 - Last mean reward per episode: 23.98
# Num timesteps: 7000
# Best mean reward: 26.58 - Last mean reward per episode: 22.81
# Num timesteps: 8000
# Best mean reward: 26.58 - Last mean reward per episode: 22.68
# Num timesteps: 9000
# Best mean reward: 26.58 - Last mean reward per episode: 21.54
# Num timesteps: 10000
# Best mean reward: 26.58 - Last mean reward per episode: 20.60
# Num timesteps: 11000
# Best mean reward: 26.58 - Last mean reward per episode: 20.74
# Num timesteps: 12000
# Best mean reward: 26.58 - Last mean reward per episode: 21.07
# Num timesteps: 13000
# Best mean reward: 26.58 - Last mean reward per episode: 21.73
# Num timesteps: 14000
# Best mean reward: 26.58 - Last mean reward per episode: 21.97
# Num timesteps: 15000
# Best mean reward: 26.58 - Last mean reward per episode: 23.65
# Num timesteps: 16000
# Best mean reward: 26.58 - Last mean reward per episode: 23.39
# Num timesteps: 17000
# Best mean reward: 26.58 - Last mean reward per episode: 20.54
# Num timesteps: 18000
# Best mean reward: 26.58 - Last mean reward per episode: 20.75
# Num timesteps: 19000
# Best mean reward: 26.58 - Last mean reward per episode: 21.74
# Num timesteps: 20000
# Best mean reward: 26.58 - Last mean reward per episode: 22.76
# Num timesteps: 21000
# Best mean reward: 26.58 - Last mean reward per episode: 23.17
# Num timesteps: 22000
# Best mean reward: 26.58 - Last mean reward per episode: 21.88
# Num timesteps: 23000
# Best mean reward: 26.58 - Last mean reward per episode: 22.02
# Num timesteps: 24000
# Best mean reward: 26.58 - Last mean reward per episode: 22.23
# Num timesteps: 25000
# Best mean reward: 26.58 - Last mean reward per episode: 21.58
# Num timesteps: 26000
# Best mean reward: 26.58 - Last mean reward per episode: 22.45
# Num timesteps: 27000
# Best mean reward: 26.58 - Last mean reward per episode: 22.99
# Num timesteps: 28000
# Best mean reward: 26.58 - Last mean reward per episode: 22.99
# Num timesteps: 29000
# Best mean reward: 26.58 - Last mean reward per episode: 22.03
# Num timesteps: 30000
# Best mean reward: 26.58 - Last mean reward per episode: 22.26
# Num timesteps: 31000
# Best mean reward: 26.58 - Last mean reward per episode: 22.52
# Num timesteps: 32000
# Best mean reward: 26.58 - Last mean reward per episode: 23.60
# Num timesteps: 33000
# Best mean reward: 26.58 - Last mean reward per episode: 24.16
# Num timesteps: 34000
# Best mean reward: 26.58 - Last mean reward per episode: 24.41
# Num timesteps: 35000
# Best mean reward: 26.58 - Last mean reward per episode: 22.69
# Num timesteps: 36000
# Best mean reward: 26.58 - Last mean reward per episode: 22.21
# Num timesteps: 37000
# Best mean reward: 26.58 - Last mean reward per episode: 22.02
# Num timesteps: 38000
# Best mean reward: 26.58 - Last mean reward per episode: 24.04
# Num timesteps: 39000
# Best mean reward: 26.58 - Last mean reward per episode: 23.77
# Num timesteps: 40000
# Best mean reward: 26.58 - Last mean reward per episode: 22.49
# Num timesteps: 41000
# Best mean reward: 26.58 - Last mean reward per episode: 21.61
# Num timesteps: 42000
# Best mean reward: 26.58 - Last mean reward per episode: 20.49
# Num timesteps: 43000
# Best mean reward: 26.58 - Last mean reward per episode: 20.83
# Num timesteps: 44000
# Best mean reward: 26.58 - Last mean reward per episode: 23.27
# Num timesteps: 45000
# Best mean reward: 26.58 - Last mean reward per episode: 24.42
# Num timesteps: 46000
# Best mean reward: 26.58 - Last mean reward per episode: 22.71
# Num timesteps: 47000
# Best mean reward: 26.58 - Last mean reward per episode: 22.16
# Num timesteps: 48000
# Best mean reward: 26.58 - Last mean reward per episode: 22.83
# Num timesteps: 49000
# Best mean reward: 26.58 - Last mean reward per episode: 23.73
# Num timesteps: 50000
# Best mean reward: 26.58 - Last mean reward per episode: 23.89
# Num timesteps: 51000
# Best mean reward: 26.58 - Last mean reward per episode: 9.58
# Num timesteps: 52000
# Best mean reward: 26.58 - Last mean reward per episode: 10.43
# Num timesteps: 53000
# Best mean reward: 26.58 - Last mean reward per episode: 12.25
# Num timesteps: 54000
# Best mean reward: 26.58 - Last mean reward per episode: 11.38
# Num timesteps: 55000
# Best mean reward: 26.58 - Last mean reward per episode: 10.02
# Num timesteps: 56000
# Best mean reward: 26.58 - Last mean reward per episode: 9.50
# Num timesteps: 57000
# Best mean reward: 26.58 - Last mean reward per episode: 9.47
# Num timesteps: 58000
# Best mean reward: 26.58 - Last mean reward per episode: 9.61
# Num timesteps: 59000
# Best mean reward: 26.58 - Last mean reward per episode: 9.79
# Num timesteps: 60000
# Best mean reward: 26.58 - Last mean reward per episode: 9.74
# Num timesteps: 61000
# Best mean reward: 26.58 - Last mean reward per episode: 9.73
# Num timesteps: 62000
# Best mean reward: 26.58 - Last mean reward per episode: 9.56
# Num timesteps: 63000
# Best mean reward: 26.58 - Last mean reward per episode: 9.56
# Num timesteps: 64000
# Best mean reward: 26.58 - Last mean reward per episode: 9.79
# Num timesteps: 65000
# Best mean reward: 26.58 - Last mean reward per episode: 9.68
# Num timesteps: 66000
# Best mean reward: 26.58 - Last mean reward per episode: 9.63
# Num timesteps: 67000
# Best mean reward: 26.58 - Last mean reward per episode: 9.61
# Num timesteps: 68000
# Best mean reward: 26.58 - Last mean reward per episode: 9.55
# Num timesteps: 69000
# Best mean reward: 26.58 - Last mean reward per episode: 9.78
# Num timesteps: 70000
# Best mean reward: 26.58 - Last mean reward per episode: 9.86
# Num timesteps: 71000
# Best mean reward: 26.58 - Last mean reward per episode: 13.77
# Num timesteps: 72000
# Best mean reward: 26.58 - Last mean reward per episode: 17.15
# Num timesteps: 73000
# Best mean reward: 26.58 - Last mean reward per episode: 13.46
# Num timesteps: 74000
# Best mean reward: 26.58 - Last mean reward per episode: 17.81
# Num timesteps: 75000
# Best mean reward: 26.58 - Last mean reward per episode: 13.02
# Num timesteps: 76000
# Best mean reward: 26.58 - Last mean reward per episode: 14.83
# Num timesteps: 77000
# Best mean reward: 26.58 - Last mean reward per episode: 13.25
# Num timesteps: 78000
# Best mean reward: 26.58 - Last mean reward per episode: 13.55
# Num timesteps: 79000
# Best mean reward: 26.58 - Last mean reward per episode: 12.06
# Num timesteps: 80000
# Best mean reward: 26.58 - Last mean reward per episode: 13.57
# Num timesteps: 81000
# Best mean reward: 26.58 - Last mean reward per episode: 20.10
# Num timesteps: 82000
# Best mean reward: 26.58 - Last mean reward per episode: 28.64
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 83000
# Best mean reward: 28.64 - Last mean reward per episode: 38.73
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 84000
# Best mean reward: 38.73 - Last mean reward per episode: 47.86
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 85000
# Best mean reward: 47.86 - Last mean reward per episode: 57.59
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 86000
# Best mean reward: 57.59 - Last mean reward per episode: 66.79
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 87000
# Best mean reward: 66.79 - Last mean reward per episode: 75.73
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 88000
# Best mean reward: 75.73 - Last mean reward per episode: 84.43
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 89000
# Best mean reward: 84.43 - Last mean reward per episode: 94.09
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 90000
# Best mean reward: 94.09 - Last mean reward per episode: 103.61
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 91000
# Best mean reward: 103.61 - Last mean reward per episode: 112.89
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 92000
# Best mean reward: 112.89 - Last mean reward per episode: 121.49
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 93000
# Best mean reward: 121.49 - Last mean reward per episode: 129.72
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 94000
# Best mean reward: 129.72 - Last mean reward per episode: 140.47
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 95000
# Best mean reward: 140.47 - Last mean reward per episode: 149.77
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 96000
# Best mean reward: 149.77 - Last mean reward per episode: 158.67
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 97000
# Best mean reward: 158.67 - Last mean reward per episode: 168.32
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 98000
# Best mean reward: 168.32 - Last mean reward per episode: 177.61
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 99000
# Best mean reward: 177.61 - Last mean reward per episode: 176.95
# Num timesteps: 100000
# Best mean reward: 177.61 - Last mean reward per episode: 176.86
# Num timesteps: 101000
# Best mean reward: 177.61 - Last mean reward per episode: 178.14
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 102000
# Best mean reward: 178.14 - Last mean reward per episode: 177.89
# Num timesteps: 103000
# Best mean reward: 178.14 - Last mean reward per episode: 176.19
# Num timesteps: 104000
# Best mean reward: 178.14 - Last mean reward per episode: 174.95
# Num timesteps: 105000
# Best mean reward: 178.14 - Last mean reward per episode: 173.85
# Num timesteps: 106000
# Best mean reward: 178.14 - Last mean reward per episode: 173.74
# Num timesteps: 107000
# Best mean reward: 178.14 - Last mean reward per episode: 173.76
# Num timesteps: 108000
# Best mean reward: 178.14 - Last mean reward per episode: 173.61
# Num timesteps: 109000
# Best mean reward: 178.14 - Last mean reward per episode: 173.00
# Num timesteps: 110000
# Best mean reward: 178.14 - Last mean reward per episode: 172.81
# Num timesteps: 111000
# Best mean reward: 178.14 - Last mean reward per episode: 172.31
# Num timesteps: 112000
# Best mean reward: 178.14 - Last mean reward per episode: 170.87
# Num timesteps: 113000
# Best mean reward: 178.14 - Last mean reward per episode: 170.25
# Num timesteps: 114000
# Best mean reward: 178.14 - Last mean reward per episode: 169.83
# Num timesteps: 115000
# Best mean reward: 178.14 - Last mean reward per episode: 170.36
# Num timesteps: 116000
# Best mean reward: 178.14 - Last mean reward per episode: 170.92
# Num timesteps: 117000
# Best mean reward: 178.14 - Last mean reward per episode: 172.05
# Num timesteps: 118000
# Best mean reward: 178.14 - Last mean reward per episode: 171.24
# Num timesteps: 119000
# Best mean reward: 178.14 - Last mean reward per episode: 170.97
# Num timesteps: 120000
# Best mean reward: 178.14 - Last mean reward per episode: 171.23
# Num timesteps: 121000
# Best mean reward: 178.14 - Last mean reward per episode: 172.76
# Num timesteps: 122000
# Best mean reward: 178.14 - Last mean reward per episode: 172.23
# Num timesteps: 123000
# Best mean reward: 178.14 - Last mean reward per episode: 172.83
# Num timesteps: 124000
# Best mean reward: 178.14 - Last mean reward per episode: 173.23
# Num timesteps: 125000
# Best mean reward: 178.14 - Last mean reward per episode: 173.54
# Num timesteps: 126000
# Best mean reward: 178.14 - Last mean reward per episode: 175.40
# Num timesteps: 127000
# Best mean reward: 178.14 - Last mean reward per episode: 176.24
# Num timesteps: 128000
# Best mean reward: 178.14 - Last mean reward per episode: 176.74
# Num timesteps: 129000
# Best mean reward: 178.14 - Last mean reward per episode: 176.06
# Num timesteps: 130000
# Best mean reward: 178.14 - Last mean reward per episode: 176.78
# Num timesteps: 131000
# Best mean reward: 178.14 - Last mean reward per episode: 174.92
# Num timesteps: 132000
# Best mean reward: 178.14 - Last mean reward per episode: 174.74
# Num timesteps: 133000
# Best mean reward: 178.14 - Last mean reward per episode: 175.02
# Num timesteps: 134000
# Best mean reward: 178.14 - Last mean reward per episode: 175.34
# Num timesteps: 135000
# Best mean reward: 178.14 - Last mean reward per episode: 174.93
# Num timesteps: 136000
# Best mean reward: 178.14 - Last mean reward per episode: 174.62
# Num timesteps: 137000
# Best mean reward: 178.14 - Last mean reward per episode: 174.51
# Num timesteps: 138000
# Best mean reward: 178.14 - Last mean reward per episode: 174.03
# Num timesteps: 139000
# Best mean reward: 178.14 - Last mean reward per episode: 173.59
# Num timesteps: 140000
# Best mean reward: 178.14 - Last mean reward per episode: 173.57
# Num timesteps: 141000
# Best mean reward: 178.14 - Last mean reward per episode: 174.35
# Num timesteps: 142000
# Best mean reward: 178.14 - Last mean reward per episode: 175.30
# Num timesteps: 143000
# Best mean reward: 178.14 - Last mean reward per episode: 176.62
# Num timesteps: 144000
# Best mean reward: 178.14 - Last mean reward per episode: 176.33
# Num timesteps: 145000
# Best mean reward: 178.14 - Last mean reward per episode: 175.55
# Num timesteps: 146000
# Best mean reward: 178.14 - Last mean reward per episode: 176.08
# Num timesteps: 147000
# Best mean reward: 178.14 - Last mean reward per episode: 175.50
# Num timesteps: 148000
# Best mean reward: 178.14 - Last mean reward per episode: 176.32
# Num timesteps: 149000
# Best mean reward: 178.14 - Last mean reward per episode: 178.24
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 150000
# Best mean reward: 178.24 - Last mean reward per episode: 179.21
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 151000
# Best mean reward: 179.21 - Last mean reward per episode: 178.71
# Num timesteps: 152000
# Best mean reward: 179.21 - Last mean reward per episode: 178.32
# Num timesteps: 153000
# Best mean reward: 179.21 - Last mean reward per episode: 179.13
# Num timesteps: 154000
# Best mean reward: 179.21 - Last mean reward per episode: 180.13
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 155000
# Best mean reward: 180.13 - Last mean reward per episode: 180.43
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 156000
# Best mean reward: 180.43 - Last mean reward per episode: 181.03
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 157000
# Best mean reward: 181.03 - Last mean reward per episode: 181.92
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/3. Deep Q-Learning/tmp/best_model.zip
# Num timesteps: 158000
# Best mean reward: 181.92 - Last mean reward per episode: 181.66
# Num timesteps: 159000
# Best mean reward: 181.92 - Last mean reward per episode: 181.22
# Num timesteps: 160000
# Best mean reward: 181.92 - Last mean reward per episode: 179.53
# Num timesteps: 161000
# Best mean reward: 181.92 - Last mean reward per episode: 178.86
# Num timesteps: 162000
# Best mean reward: 181.92 - Last mean reward per episode: 178.29
# Num timesteps: 163000
# Best mean reward: 181.92 - Last mean reward per episode: 178.04
# Num timesteps: 164000
# Best mean reward: 181.92 - Last mean reward per episode: 178.10
# Num timesteps: 165000
# Best mean reward: 181.92 - Last mean reward per episode: 177.32
# Num timesteps: 166000
# Best mean reward: 181.92 - Last mean reward per episode: 176.39
# Num timesteps: 167000
# Best mean reward: 181.92 - Last mean reward per episode: 174.83
# Num timesteps: 168000
# Best mean reward: 181.92 - Last mean reward per episode: 174.37
# Num timesteps: 169000
# Best mean reward: 181.92 - Last mean reward per episode: 174.41
# Num timesteps: 170000
# Best mean reward: 181.92 - Last mean reward per episode: 175.41
# Num timesteps: 171000
# Best mean reward: 181.92 - Last mean reward per episode: 174.71
# Num timesteps: 172000
# Best mean reward: 181.92 - Last mean reward per episode: 174.49
# Num timesteps: 173000
# Best mean reward: 181.92 - Last mean reward per episode: 174.31
# Num timesteps: 174000
# Best mean reward: 181.92 - Last mean reward per episode: 173.14
# Num timesteps: 175000
# Best mean reward: 181.92 - Last mean reward per episode: 171.87
# Num timesteps: 176000
# Best mean reward: 181.92 - Last mean reward per episode: 170.06
# Num timesteps: 177000
# Best mean reward: 181.92 - Last mean reward per episode: 170.38
# Num timesteps: 178000
# Best mean reward: 181.92 - Last mean reward per episode: 169.94
# Num timesteps: 179000
# Best mean reward: 181.92 - Last mean reward per episode: 169.70
# Num timesteps: 180000
# Best mean reward: 181.92 - Last mean reward per episode: 168.63
# Num timesteps: 181000
# Best mean reward: 181.92 - Last mean reward per episode: 168.21
# Num timesteps: 182000
# Best mean reward: 181.92 - Last mean reward per episode: 168.68
# Num timesteps: 183000
# Best mean reward: 181.92 - Last mean reward per episode: 168.99
# Num timesteps: 184000
# Best mean reward: 181.92 - Last mean reward per episode: 170.33
# Num timesteps: 185000
# Best mean reward: 181.92 - Last mean reward per episode: 171.26
# Num timesteps: 186000
# Best mean reward: 181.92 - Last mean reward per episode: 170.65
# Num timesteps: 187000
# Best mean reward: 181.92 - Last mean reward per episode: 171.19
# Num timesteps: 188000
# Best mean reward: 181.92 - Last mean reward per episode: 171.09
# Num timesteps: 189000
# Best mean reward: 181.92 - Last mean reward per episode: 171.12
# Num timesteps: 190000
# Best mean reward: 181.92 - Last mean reward per episode: 170.19
# Num timesteps: 191000
# Best mean reward: 181.92 - Last mean reward per episode: 170.78
# Num timesteps: 192000
# Best mean reward: 181.92 - Last mean reward per episode: 172.23
# Num timesteps: 193000
# Best mean reward: 181.92 - Last mean reward per episode: 171.95
# Num timesteps: 194000
# Best mean reward: 181.92 - Last mean reward per episode: 171.90
# Num timesteps: 195000
# Best mean reward: 181.92 - Last mean reward per episode: 172.11
# Num timesteps: 196000
# Best mean reward: 181.92 - Last mean reward per episode: 172.49
# Num timesteps: 197000
# Best mean reward: 181.92 - Last mean reward per episode: 172.68
# Num timesteps: 198000
# Best mean reward: 181.92 - Last mean reward per episode: 171.62
# Num timesteps: 199000
# Best mean reward: 181.92 - Last mean reward per episode: 170.49
# Num timesteps: 200000
# Best mean reward: 181.92 - Last mean reward per episode: 169.41

# %%
# Plotting

def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, 'valid')


def plot_results(log_folder, title='Learning Curve'):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    
    x, y = ts2xy(load_results(log_folder), 'timesteps')

    y_mean = moving_average(y, window=50)
    # Truncate x
    x_mean = x[len(x) - len(y_mean):]

    fig = plt.figure(title)
    plt.plot(x, y, alpha=0.4, label="Rewards")
    plt.plot(x_mean, y_mean, label="Mean rewards - wd:50")
    plt.xlabel('Number of Timesteps')
    plt.ylabel('Rewards')
    plt.title(title)
    plt.legend(loc="best")
    plt.show()


plot_results(log_dir)

# %%
# Test 

scores = []
for i in range(100):
    obs = env.reset()
    score = 0
    done = False
    
    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        score += reward
    
    scores.append(score)

np.mean(scores)
# Out:
# 161.94
