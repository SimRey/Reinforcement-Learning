# %%
import gym
import numpy as np

from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

# %%
env = gym.make("Pendulum-v0")

# The noise objects for DDPG
n_actions = env.action_space.shape[-1]
action_noise = OrnsteinUhlenbeckActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# %%
model = DDPG("MlpPolicy", env, action_noise=action_noise, verbose=1)
model.learn(total_timesteps=10000, log_interval=10)
model.save("ddpg_pendulum")
env = model.get_env()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.38e+03 |
# | time/              |           |
# |    episodes        | 10        |
# |    fps             | 49        |
# |    time_elapsed    | 40        |
# |    total_timesteps | 2000      |
# | train/             |           |
# |    actor_loss      | 55.3      |
# |    critic_loss     | 0.256     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1800      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 200       |
# |    ep_rew_mean     | -1.12e+03 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 39        |
# |    time_elapsed    | 100       |
# |    total_timesteps | 4000      |
# | train/             |           |
# |    actor_loss      | 83.9      |
# |    critic_loss     | 0.51      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3800      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -807     |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 36       |
# |    time_elapsed    | 162      |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | 80       |
# |    critic_loss     | 1.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -633     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 35       |
# |    time_elapsed    | 224      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | 67.5     |
# |    critic_loss     | 1.65     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -531     |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 34       |
# |    time_elapsed    | 287      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | 48.6     |
# |    critic_loss     | 1.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9800     |
# ---------------------------------

# %%
scores = []
for i in range(100):
    obs = env.reset()
    score = 0
    done = False
    
    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        score += reward
    
    scores.append(score)

scores
# Out:
# [array([-124.33081], dtype=float32),
#  array([-126.95367], dtype=float32),
#  array([-116.89191], dtype=float32),
#  array([-321.63882], dtype=float32),
#  array([-239.00049], dtype=float32),
#  array([-312.9167], dtype=float32),
#  array([-1.656664], dtype=float32),
#  array([-1.5864592], dtype=float32),
#  array([-1.4678514], dtype=float32),
#  array([-121.05871], dtype=float32),
#  array([-345.7332], dtype=float32),
#  array([-118.3028], dtype=float32),
#  array([-234.81154], dtype=float32),
#  array([-126.44826], dtype=float32),
#  array([-223.98578], dtype=float32),
#  array([-120.044075], dtype=float32),
#  array([-4.2052064], dtype=float32),
#  array([-120.47144], dtype=float32),
#  array([-122.239876], dtype=float32),
#  array([-123.69418], dtype=float32),
#  array([-115.3385], dtype=float32),
#  array([-225.2278], dtype=float32),
#  array([-4.332299], dtype=float32),
#  array([-2.4494426], dtype=float32),
#  array([-119.09205], dtype=float32),
#  array([-238.41634], dtype=float32),
#  array([-120.038574], dtype=float32),
#  array([-224.47798], dtype=float32),
#  array([-234.63142], dtype=float32),
#  array([-120.78119], dtype=float32),
#  array([-241.25465], dtype=float32),
#  array([-232.31148], dtype=float32),
#  array([-123.954124], dtype=float32),
#  array([-241.11632], dtype=float32),
#  array([-120.25464], dtype=float32),
#  array([-121.34826], dtype=float32),
#  array([-117.5562], dtype=float32),
#  array([-117.55215], dtype=float32),
#  array([-120.26526], dtype=float32),
#  array([-2.5074632], dtype=float32),
#  array([-325.38156], dtype=float32),
#  array([-129.02608], dtype=float32),
#  array([-231.37288], dtype=float32),
#  array([-236.93675], dtype=float32),
#  array([-117.72392], dtype=float32),
#  array([-118.1057], dtype=float32),
#  array([-241.14775], dtype=float32),
#  array([-1.427743], dtype=float32),
#  array([-246.39392], dtype=float32),
#  array([-116.94033], dtype=float32),
#  array([-122.76782], dtype=float32),
#  array([-120.46526], dtype=float32),
#  array([-118.89848], dtype=float32),
#  array([-286.08487], dtype=float32),
#  array([-277.19037], dtype=float32),
#  array([-115.571434], dtype=float32),
#  array([-229.59238], dtype=float32),
#  array([-125.60172], dtype=float32),
#  array([-273.24338], dtype=float32),
#  array([-228.00864], dtype=float32),
#  array([-123.452896], dtype=float32),
#  array([-321.32712], dtype=float32),
#  array([-3.085175], dtype=float32),
#  array([-120.25276], dtype=float32),
#  array([-117.29038], dtype=float32),
#  array([-124.209694], dtype=float32),
#  array([-117.151886], dtype=float32),
#  array([-229.8844], dtype=float32),
#  array([-223.67897], dtype=float32),
#  array([-2.195073], dtype=float32),
#  array([-120.84771], dtype=float32),
#  array([-236.11581], dtype=float32),
#  array([-343.00018], dtype=float32),
#  array([-238.57062], dtype=float32),
#  array([-114.29384], dtype=float32),
#  array([-121.59233], dtype=float32),
#  array([-124.000565], dtype=float32),
#  array([-125.40007], dtype=float32),
#  array([-123.867516], dtype=float32),
#  array([-123.0699], dtype=float32),
#  array([-1.5326265], dtype=float32),
#  array([-2.3457065], dtype=float32),
#  array([-127.04686], dtype=float32),
#  array([-224.46567], dtype=float32),
#  array([-233.43967], dtype=float32),
#  array([-234.89676], dtype=float32),
#  array([-124.34774], dtype=float32),
#  array([-352.74533], dtype=float32),
#  array([-236.6487], dtype=float32),
#  array([-1.5732455], dtype=float32),
#  array([-234.92624], dtype=float32),
#  array([-1.6622058], dtype=float32),
#  array([-230.64575], dtype=float32),
#  array([-128.1035], dtype=float32),
#  array([-3.479914], dtype=float32),
#  array([-228.35374], dtype=float32),
#  array([-121.670685], dtype=float32),
#  array([-119.51124], dtype=float32),
#  array([-242.71086], dtype=float32),
#  array([-120.00621], dtype=float32)]
