# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3.common import results_plotter
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), 'timesteps')
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose > 0:
                print(f"Num timesteps: {self.num_timesteps}")
                print(f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}")

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose > 0:
                    print(f"Saving new best model to {self.save_path}.zip")
                  self.model.save(self.save_path)

        return True

# %%
# Create and wrap the environment

# Create log dir
log_dir = "C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = gym.make("Pendulum-v0")
# The noise objects for DDPG
n_actions = env.action_space.shape[-1]
action_noise = OrnsteinUhlenbeckActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)
# Out:
# c:\Users\Lenovo\anaconda3\envs\myenv\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
# Create and train the agent

# Create the callback: check every 1000 steps
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)
# Create RL model
model = DDPG("MlpPolicy", env, action_noise=action_noise)
# Train the agent
model.learn(total_timesteps=int(200000), callback=callback)
# Out:
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -1391.43
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 2000
# Best mean reward: -1391.43 - Last mean reward per episode: -1315.07
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 3000
# Best mean reward: -1315.07 - Last mean reward per episode: -1162.18
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 4000
# Best mean reward: -1162.18 - Last mean reward per episode: -1041.86
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 5000
# Best mean reward: -1041.86 - Last mean reward per episode: -887.12
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 6000
# Best mean reward: -887.12 - Last mean reward per episode: -773.01
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 7000
# Best mean reward: -773.01 - Last mean reward per episode: -687.37
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 8000
# Best mean reward: -687.37 - Last mean reward per episode: -613.83
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 9000
# Best mean reward: -613.83 - Last mean reward per episode: -562.00
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 10000
# Best mean reward: -562.00 - Last mean reward per episode: -519.46
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 11000
# Best mean reward: -519.46 - Last mean reward per episode: -483.06
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 12000
# Best mean reward: -483.06 - Last mean reward per episode: -454.82
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 13000
# Best mean reward: -454.82 - Last mean reward per episode: -430.96
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 14000
# Best mean reward: -430.96 - Last mean reward per episode: -408.69
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 15000
# Best mean reward: -408.69 - Last mean reward per episode: -389.22
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 16000
# Best mean reward: -389.22 - Last mean reward per episode: -372.33
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 17000
# Best mean reward: -372.33 - Last mean reward per episode: -357.64
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 18000
# Best mean reward: -357.64 - Last mean reward per episode: -343.17
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 19000
# Best mean reward: -343.17 - Last mean reward per episode: -333.82
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 20000
# Best mean reward: -333.82 - Last mean reward per episode: -326.26
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 21000
# Best mean reward: -326.26 - Last mean reward per episode: -262.47
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 22000
# Best mean reward: -262.47 - Last mean reward per episode: -209.29
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 23000
# Best mean reward: -209.29 - Last mean reward per episode: -172.32
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 24000
# Best mean reward: -172.32 - Last mean reward per episode: -145.50
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 25000
# Best mean reward: -145.50 - Last mean reward per episode: -137.99
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 26000
# Best mean reward: -137.99 - Last mean reward per episode: -133.83
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 27000
# Best mean reward: -133.83 - Last mean reward per episode: -133.44
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 28000
# Best mean reward: -133.44 - Last mean reward per episode: -136.51
# Num timesteps: 29000
# Best mean reward: -133.44 - Last mean reward per episode: -133.86
# Num timesteps: 30000
# Best mean reward: -133.44 - Last mean reward per episode: -132.99
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 31000
# Best mean reward: -132.99 - Last mean reward per episode: -133.12
# Num timesteps: 32000
# Best mean reward: -132.99 - Last mean reward per episode: -134.66
# Num timesteps: 33000
# Best mean reward: -132.99 - Last mean reward per episode: -132.32
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/4. Policy gradient/DDPG/SB3/tmp/best_model.zip
# Num timesteps: 34000
# Best mean reward: -132.32 - Last mean reward per episode: -134.70
# Num timesteps: 35000
# Best mean reward: -132.32 - Last mean reward per episode: -133.75
# Num timesteps: 36000
# Best mean reward: -132.32 - Last mean reward per episode: -134.97
# Num timesteps: 37000
# Best mean reward: -132.32 - Last mean reward per episode: -139.32
# Num timesteps: 38000
# Best mean reward: -132.32 - Last mean reward per episode: -139.43
# Num timesteps: 39000
# Best mean reward: -132.32 - Last mean reward per episode: -138.49
# Num timesteps: 40000
# Best mean reward: -132.32 - Last mean reward per episode: -134.37
# Num timesteps: 41000
# Best mean reward: -132.32 - Last mean reward per episode: -134.59
# Num timesteps: 42000
# Best mean reward: -132.32 - Last mean reward per episode: -133.10
# Num timesteps: 43000
# Best mean reward: -132.32 - Last mean reward per episode: -135.74
# Num timesteps: 44000
# Best mean reward: -132.32 - Last mean reward per episode: -133.24
# Num timesteps: 45000
# Best mean reward: -132.32 - Last mean reward per episode: -134.52
# Num timesteps: 46000
# Best mean reward: -132.32 - Last mean reward per episode: -136.66
# Num timesteps: 47000
# Best mean reward: -132.32 - Last mean reward per episode: -136.46
# Num timesteps: 48000
# Best mean reward: -132.32 - Last mean reward per episode: -135.08
# Num timesteps: 49000
# Best mean reward: -132.32 - Last mean reward per episode: -137.62
# Num timesteps: 50000
# Best mean reward: -132.32 - Last mean reward per episode: -141.09
# Num timesteps: 51000
# Best mean reward: -132.32 - Last mean reward per episode: -148.34
# Num timesteps: 52000
# Best mean reward: -132.32 - Last mean reward per episode: -146.48
# Num timesteps: 53000
# Best mean reward: -132.32 - Last mean reward per episode: -152.38
# Num timesteps: 54000
# Best mean reward: -132.32 - Last mean reward per episode: -152.68
# Num timesteps: 55000
# Best mean reward: -132.32 - Last mean reward per episode: -152.76
# Num timesteps: 56000
# Best mean reward: -132.32 - Last mean reward per episode: -153.05
# Num timesteps: 57000
# Best mean reward: -132.32 - Last mean reward per episode: -148.53
# Num timesteps: 58000
# Best mean reward: -132.32 - Last mean reward per episode: -152.02
# Num timesteps: 59000
# Best mean reward: -132.32 - Last mean reward per episode: -161.65
# Num timesteps: 60000
# Best mean reward: -132.32 - Last mean reward per episode: -164.81
# Num timesteps: 61000
# Best mean reward: -132.32 - Last mean reward per episode: -167.66
# Num timesteps: 62000
# Best mean reward: -132.32 - Last mean reward per episode: -167.67
# Num timesteps: 63000
# Best mean reward: -132.32 - Last mean reward per episode: -170.16
# Num timesteps: 64000
# Best mean reward: -132.32 - Last mean reward per episode: -171.55
# Num timesteps: 65000
# Best mean reward: -132.32 - Last mean reward per episode: -171.73
# Num timesteps: 66000
# Best mean reward: -132.32 - Last mean reward per episode: -173.11
# Num timesteps: 67000
# Best mean reward: -132.32 - Last mean reward per episode: -174.39
# Num timesteps: 68000
# Best mean reward: -132.32 - Last mean reward per episode: -173.68
# Num timesteps: 69000
# Best mean reward: -132.32 - Last mean reward per episode: -176.72
# Num timesteps: 70000
# Best mean reward: -132.32 - Last mean reward per episode: -173.24
# Num timesteps: 71000
# Best mean reward: -132.32 - Last mean reward per episode: -168.25
# Num timesteps: 72000
# Best mean reward: -132.32 - Last mean reward per episode: -168.19
# Num timesteps: 73000
# Best mean reward: -132.32 - Last mean reward per episode: -162.11
# Num timesteps: 74000
# Best mean reward: -132.32 - Last mean reward per episode: -160.61
# Num timesteps: 75000
# Best mean reward: -132.32 - Last mean reward per episode: -163.75
# Num timesteps: 76000
# Best mean reward: -132.32 - Last mean reward per episode: -163.21
# Num timesteps: 77000
# Best mean reward: -132.32 - Last mean reward per episode: -165.65
# Num timesteps: 78000
# Best mean reward: -132.32 - Last mean reward per episode: -163.26
# Num timesteps: 79000
# Best mean reward: -132.32 - Last mean reward per episode: -149.73
# Num timesteps: 80000
# Best mean reward: -132.32 - Last mean reward per episode: -148.31
# Num timesteps: 81000
# Best mean reward: -132.32 - Last mean reward per episode: -147.32
# Num timesteps: 82000
# Best mean reward: -132.32 - Last mean reward per episode: -145.98
# Num timesteps: 83000
# Best mean reward: -132.32 - Last mean reward per episode: -144.05
# Num timesteps: 84000
# Best mean reward: -132.32 - Last mean reward per episode: -145.87
# Num timesteps: 85000
# Best mean reward: -132.32 - Last mean reward per episode: -146.58
# Num timesteps: 86000
# Best mean reward: -132.32 - Last mean reward per episode: -148.05
# Num timesteps: 87000
# Best mean reward: -132.32 - Last mean reward per episode: -148.38
# Num timesteps: 88000
# Best mean reward: -132.32 - Last mean reward per episode: -147.51
# Num timesteps: 89000
# Best mean reward: -132.32 - Last mean reward per episode: -143.78
# Num timesteps: 90000
# Best mean reward: -132.32 - Last mean reward per episode: -144.95
# Num timesteps: 91000
# Best mean reward: -132.32 - Last mean reward per episode: -142.64
# Num timesteps: 92000
# Best mean reward: -132.32 - Last mean reward per episode: -146.25
# Num timesteps: 93000
# Best mean reward: -132.32 - Last mean reward per episode: -146.46
# Num timesteps: 94000
# Best mean reward: -132.32 - Last mean reward per episode: -147.86
# Num timesteps: 95000
# Best mean reward: -132.32 - Last mean reward per episode: -147.05
# Num timesteps: 96000
# Best mean reward: -132.32 - Last mean reward per episode: -146.66
# Num timesteps: 97000
# Best mean reward: -132.32 - Last mean reward per episode: -148.26
# Num timesteps: 98000
# Best mean reward: -132.32 - Last mean reward per episode: -149.61
# Num timesteps: 99000
# Best mean reward: -132.32 - Last mean reward per episode: -156.27
# Num timesteps: 100000
# Best mean reward: -132.32 - Last mean reward per episode: -154.44
# Num timesteps: 101000
# Best mean reward: -132.32 - Last mean reward per episode: -156.56
# Num timesteps: 102000
# Best mean reward: -132.32 - Last mean reward per episode: -160.23
# Num timesteps: 103000
# Best mean reward: -132.32 - Last mean reward per episode: -158.35
# Num timesteps: 104000
# Best mean reward: -132.32 - Last mean reward per episode: -155.28
# Num timesteps: 105000
# Best mean reward: -132.32 - Last mean reward per episode: -153.26
# Num timesteps: 106000
# Best mean reward: -132.32 - Last mean reward per episode: -149.44
# Num timesteps: 107000
# Best mean reward: -132.32 - Last mean reward per episode: -145.81
# Num timesteps: 108000
# Best mean reward: -132.32 - Last mean reward per episode: -150.96
# Num timesteps: 109000
# Best mean reward: -132.32 - Last mean reward per episode: -150.37
# Num timesteps: 110000
# Best mean reward: -132.32 - Last mean reward per episode: -149.91
# Num timesteps: 111000
# Best mean reward: -132.32 - Last mean reward per episode: -152.13
# Num timesteps: 112000
# Best mean reward: -132.32 - Last mean reward per episode: -146.67
# Num timesteps: 113000
# Best mean reward: -132.32 - Last mean reward per episode: -150.18
# Num timesteps: 114000
# Best mean reward: -132.32 - Last mean reward per episode: -149.03
# Num timesteps: 115000
# Best mean reward: -132.32 - Last mean reward per episode: -149.94
# Num timesteps: 116000
# Best mean reward: -132.32 - Last mean reward per episode: -151.71
# Num timesteps: 117000
# Best mean reward: -132.32 - Last mean reward per episode: -150.09
# Num timesteps: 118000
# Best mean reward: -132.32 - Last mean reward per episode: -150.05
# Num timesteps: 119000
# Best mean reward: -132.32 - Last mean reward per episode: -145.95
# Num timesteps: 120000
# Best mean reward: -132.32 - Last mean reward per episode: -145.87
# Num timesteps: 121000
# Best mean reward: -132.32 - Last mean reward per episode: -140.86
# Num timesteps: 122000
# Best mean reward: -132.32 - Last mean reward per episode: -135.11
# Num timesteps: 123000
# Best mean reward: -132.32 - Last mean reward per episode: -132.78
# Num timesteps: 124000
# Best mean reward: -132.32 - Last mean reward per episode: -137.46
# Num timesteps: 125000
# Best mean reward: -132.32 - Last mean reward per episode: -141.03
# Num timesteps: 126000
# Best mean reward: -132.32 - Last mean reward per episode: -143.83
# Num timesteps: 127000
# Best mean reward: -132.32 - Last mean reward per episode: -144.73
# Num timesteps: 128000
# Best mean reward: -132.32 - Last mean reward per episode: -140.76
# Num timesteps: 129000
# Best mean reward: -132.32 - Last mean reward per episode: -142.16
# Num timesteps: 130000
# Best mean reward: -132.32 - Last mean reward per episode: -141.42
# Num timesteps: 131000
# Best mean reward: -132.32 - Last mean reward per episode: -139.12
# Num timesteps: 132000
# Best mean reward: -132.32 - Last mean reward per episode: -143.51
# Num timesteps: 133000
# Best mean reward: -132.32 - Last mean reward per episode: -143.12
# Num timesteps: 134000
# Best mean reward: -132.32 - Last mean reward per episode: -146.07
# Num timesteps: 135000
# Best mean reward: -132.32 - Last mean reward per episode: -142.71
# Num timesteps: 136000
# Best mean reward: -132.32 - Last mean reward per episode: -140.52
# Num timesteps: 137000
# Best mean reward: -132.32 - Last mean reward per episode: -140.00
# Num timesteps: 138000
# Best mean reward: -132.32 - Last mean reward per episode: -141.98
# Num timesteps: 139000
# Best mean reward: -132.32 - Last mean reward per episode: -141.79
# Num timesteps: 140000
# Best mean reward: -132.32 - Last mean reward per episode: -145.07
# Num timesteps: 141000
# Best mean reward: -132.32 - Last mean reward per episode: -146.01
# Num timesteps: 142000
# Best mean reward: -132.32 - Last mean reward per episode: -149.19
# Num timesteps: 143000
# Best mean reward: -132.32 - Last mean reward per episode: -154.53
# Num timesteps: 144000
# Best mean reward: -132.32 - Last mean reward per episode: -151.28
# Num timesteps: 145000
# Best mean reward: -132.32 - Last mean reward per episode: -149.89
# Num timesteps: 146000
# Best mean reward: -132.32 - Last mean reward per episode: -146.98
# Num timesteps: 147000
# Best mean reward: -132.32 - Last mean reward per episode: -144.81
# Num timesteps: 148000
# Best mean reward: -132.32 - Last mean reward per episode: -144.43
# Num timesteps: 149000
# Best mean reward: -132.32 - Last mean reward per episode: -145.27
# Num timesteps: 150000
# Best mean reward: -132.32 - Last mean reward per episode: -148.71
# Num timesteps: 151000
# Best mean reward: -132.32 - Last mean reward per episode: -148.60
# Num timesteps: 152000
# Best mean reward: -132.32 - Last mean reward per episode: -147.62
# Num timesteps: 153000
# Best mean reward: -132.32 - Last mean reward per episode: -145.48
# Num timesteps: 154000
# Best mean reward: -132.32 - Last mean reward per episode: -141.25
# Num timesteps: 155000
# Best mean reward: -132.32 - Last mean reward per episode: -145.78
# Num timesteps: 156000
# Best mean reward: -132.32 - Last mean reward per episode: -144.62
# Num timesteps: 157000
# Best mean reward: -132.32 - Last mean reward per episode: -141.78
# Num timesteps: 158000
# Best mean reward: -132.32 - Last mean reward per episode: -141.33
# Num timesteps: 159000
# Best mean reward: -132.32 - Last mean reward per episode: -142.74
# Num timesteps: 160000
# Best mean reward: -132.32 - Last mean reward per episode: -141.65
# Num timesteps: 161000
# Best mean reward: -132.32 - Last mean reward per episode: -141.65
# Num timesteps: 162000
# Best mean reward: -132.32 - Last mean reward per episode: -141.69
# Num timesteps: 163000
# Best mean reward: -132.32 - Last mean reward per episode: -137.48
# Num timesteps: 164000
# Best mean reward: -132.32 - Last mean reward per episode: -138.15
# Num timesteps: 165000
# Best mean reward: -132.32 - Last mean reward per episode: -135.95
# Num timesteps: 166000
# Best mean reward: -132.32 - Last mean reward per episode: -139.51
# Num timesteps: 167000
# Best mean reward: -132.32 - Last mean reward per episode: -145.84
# Num timesteps: 168000
# Best mean reward: -132.32 - Last mean reward per episode: -144.64
# Num timesteps: 169000
# Best mean reward: -132.32 - Last mean reward per episode: -140.17
# Num timesteps: 170000
# Best mean reward: -132.32 - Last mean reward per episode: -136.68
# Num timesteps: 171000
# Best mean reward: -132.32 - Last mean reward per episode: -136.51
# Num timesteps: 172000
# Best mean reward: -132.32 - Last mean reward per episode: -135.25
# Num timesteps: 173000
# Best mean reward: -132.32 - Last mean reward per episode: -134.22
# Num timesteps: 174000
# Best mean reward: -132.32 - Last mean reward per episode: -133.92
# Num timesteps: 175000
# Best mean reward: -132.32 - Last mean reward per episode: -135.04
# Num timesteps: 176000
# Best mean reward: -132.32 - Last mean reward per episode: -138.32
# Num timesteps: 177000
# Best mean reward: -132.32 - Last mean reward per episode: -142.12
# Num timesteps: 178000
# Best mean reward: -132.32 - Last mean reward per episode: -142.59
# Num timesteps: 179000
# Best mean reward: -132.32 - Last mean reward per episode: -141.03
# Num timesteps: 180000
# Best mean reward: -132.32 - Last mean reward per episode: -142.23
# Num timesteps: 181000
# Best mean reward: -132.32 - Last mean reward per episode: -143.33
# Num timesteps: 182000
# Best mean reward: -132.32 - Last mean reward per episode: -143.26
# Num timesteps: 183000
# Best mean reward: -132.32 - Last mean reward per episode: -143.34
# Num timesteps: 184000
# Best mean reward: -132.32 - Last mean reward per episode: -145.99
# Num timesteps: 185000
# Best mean reward: -132.32 - Last mean reward per episode: -147.29
# Num timesteps: 186000
# Best mean reward: -132.32 - Last mean reward per episode: -144.96
# Num timesteps: 187000
# Best mean reward: -132.32 - Last mean reward per episode: -146.03
# Num timesteps: 188000
# Best mean reward: -132.32 - Last mean reward per episode: -150.80
# Num timesteps: 189000
# Best mean reward: -132.32 - Last mean reward per episode: -154.04
# Num timesteps: 190000
# Best mean reward: -132.32 - Last mean reward per episode: -153.14
# Num timesteps: 191000
# Best mean reward: -132.32 - Last mean reward per episode: -156.74
# Num timesteps: 192000
# Best mean reward: -132.32 - Last mean reward per episode: -153.25
# Num timesteps: 193000
# Best mean reward: -132.32 - Last mean reward per episode: -158.63
# Num timesteps: 194000
# Best mean reward: -132.32 - Last mean reward per episode: -157.61
# Num timesteps: 195000
# Best mean reward: -132.32 - Last mean reward per episode: -155.41
# Num timesteps: 196000
# Best mean reward: -132.32 - Last mean reward per episode: -153.38
# Num timesteps: 197000
# Best mean reward: -132.32 - Last mean reward per episode: -148.22
# Num timesteps: 198000
# Best mean reward: -132.32 - Last mean reward per episode: -146.12
# Num timesteps: 199000
# Best mean reward: -132.32 - Last mean reward per episode: -148.76
# Num timesteps: 200000
# Best mean reward: -132.32 - Last mean reward per episode: -147.59

# %%
# Plotting

def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, 'valid')


def plot_results(log_folder, title='Learning Curve'):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    
    x, y = ts2xy(load_results(log_folder), 'timesteps')

    y_mean = moving_average(y, window=50)
    # Truncate x
    x_mean = x[len(x) - len(y_mean):]

    fig = plt.figure(title)
    plt.plot(x, y, alpha=0.4, label="Rewards")
    plt.plot(x_mean, y_mean, label="Mean rewards - wd:50")
    plt.xlabel('Number of Timesteps')
    plt.ylabel('Rewards')
    plt.title(title)
    plt.legend(loc="best")
    plt.show()


plot_results(log_dir)

# %%
# Test 

scores = []
for i in range(100):
    obs = env.reset()
    score = 0
    done = False
    
    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        score += reward
    
    scores.append(score)

np.mean(scores)
# Out:
# -140.78099102498535
