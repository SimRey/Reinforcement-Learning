# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3.common import results_plotter
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback

# This part allows the graph to be drawn
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), 'timesteps')
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose > 0:
                print(f"Num timesteps: {self.num_timesteps}")
                print(f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}")

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose > 0:
                    print(f"Saving new best model to {self.save_path}.zip")
                  self.model.save(self.save_path)

        return True

# %%
# Create and wrap the environment

# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = gym.make("Pendulum-v0")
# The noise objects for DDPG
n_actions = env.action_space.shape[-1]
action_noise = OrnsteinUhlenbeckActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)
# Out:
# c:\Users\Lenovo\anaconda3\envs\myenv\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
# Create and train the agent

# Create the callback: check every 1000 steps
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)
# Create RL model
model = DDPG("MlpPolicy", env, action_noise=action_noise)
# Train the agent
model.learn(total_timesteps=int(200000), callback=callback)
# Out:
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -1474.67
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2000
# Best mean reward: -1474.67 - Last mean reward per episode: -1424.69
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 3000
# Best mean reward: -1424.69 - Last mean reward per episode: -1342.41
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 4000
# Best mean reward: -1342.41 - Last mean reward per episode: -1127.55
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5000
# Best mean reward: -1127.55 - Last mean reward per episode: -941.84
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 6000
# Best mean reward: -941.84 - Last mean reward per episode: -809.04
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7000
# Best mean reward: -809.04 - Last mean reward per episode: -710.91
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 8000
# Best mean reward: -710.91 - Last mean reward per episode: -638.59
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 9000
# Best mean reward: -638.59 - Last mean reward per episode: -588.05
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 10000
# Best mean reward: -588.05 - Last mean reward per episode: -546.41
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 11000
# Best mean reward: -546.41 - Last mean reward per episode: -509.56
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 12000
# Best mean reward: -509.56 - Last mean reward per episode: -480.92
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 13000
# Best mean reward: -480.92 - Last mean reward per episode: -456.76
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 14000
# Best mean reward: -456.76 - Last mean reward per episode: -434.42
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 15000
# Best mean reward: -434.42 - Last mean reward per episode: -416.47
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 16000
# Best mean reward: -416.47 - Last mean reward per episode: -402.99
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 17000
# Best mean reward: -402.99 - Last mean reward per episode: -387.66
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 18000
# Best mean reward: -387.66 - Last mean reward per episode: -374.29
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 19000
# Best mean reward: -374.29 - Last mean reward per episode: -361.99
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 20000
# Best mean reward: -361.99 - Last mean reward per episode: -354.08
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 21000
# Best mean reward: -354.08 - Last mean reward per episode: -288.70
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 22000
# Best mean reward: -288.70 - Last mean reward per episode: -229.39
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 23000
# Best mean reward: -229.39 - Last mean reward per episode: -178.81
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 24000
# Best mean reward: -178.81 - Last mean reward per episode: -160.70
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 25000
# Best mean reward: -160.70 - Last mean reward per episode: -157.99
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 26000
# Best mean reward: -157.99 - Last mean reward per episode: -158.85
# Num timesteps: 27000
# Best mean reward: -157.99 - Last mean reward per episode: -158.72
# Num timesteps: 28000
# Best mean reward: -157.99 - Last mean reward per episode: -159.15
# Num timesteps: 29000
# Best mean reward: -157.99 - Last mean reward per episode: -157.30
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 30000
# Best mean reward: -157.30 - Last mean reward per episode: -157.23
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 31000
# Best mean reward: -157.23 - Last mean reward per episode: -160.03
# Num timesteps: 32000
# Best mean reward: -157.23 - Last mean reward per episode: -159.57
# Num timesteps: 33000
# Best mean reward: -157.23 - Last mean reward per episode: -159.58
# Num timesteps: 34000
# Best mean reward: -157.23 - Last mean reward per episode: -161.86
# Num timesteps: 35000
# Best mean reward: -157.23 - Last mean reward per episode: -159.83
# Num timesteps: 36000
# Best mean reward: -157.23 - Last mean reward per episode: -155.20
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 37000
# Best mean reward: -155.20 - Last mean reward per episode: -154.67
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 38000
# Best mean reward: -154.67 - Last mean reward per episode: -156.57
# Num timesteps: 39000
# Best mean reward: -154.67 - Last mean reward per episode: -157.59
# Num timesteps: 40000
# Best mean reward: -154.67 - Last mean reward per episode: -152.96
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 41000
# Best mean reward: -152.96 - Last mean reward per episode: -151.11
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 42000
# Best mean reward: -151.11 - Last mean reward per episode: -149.16
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 43000
# Best mean reward: -149.16 - Last mean reward per episode: -145.95
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 44000
# Best mean reward: -145.95 - Last mean reward per episode: -147.22
# Num timesteps: 45000
# Best mean reward: -145.95 - Last mean reward per episode: -150.13
# Num timesteps: 46000
# Best mean reward: -145.95 - Last mean reward per episode: -147.63
# Num timesteps: 47000
# Best mean reward: -145.95 - Last mean reward per episode: -150.42
# Num timesteps: 48000
# Best mean reward: -145.95 - Last mean reward per episode: -154.40
# Num timesteps: 49000
# Best mean reward: -145.95 - Last mean reward per episode: -153.67
# Num timesteps: 50000
# Best mean reward: -145.95 - Last mean reward per episode: -151.98
# Num timesteps: 51000
# Best mean reward: -145.95 - Last mean reward per episode: -148.60
# Num timesteps: 52000
# Best mean reward: -145.95 - Last mean reward per episode: -152.18
# Num timesteps: 53000
# Best mean reward: -145.95 - Last mean reward per episode: -155.14
# Num timesteps: 54000
# Best mean reward: -145.95 - Last mean reward per episode: -155.32
# Num timesteps: 55000
# Best mean reward: -145.95 - Last mean reward per episode: -156.66
# Num timesteps: 56000
# Best mean reward: -145.95 - Last mean reward per episode: -159.76
# Num timesteps: 57000
# Best mean reward: -145.95 - Last mean reward per episode: -161.39
# Num timesteps: 58000
# Best mean reward: -145.95 - Last mean reward per episode: -164.16
# Num timesteps: 59000
# Best mean reward: -145.95 - Last mean reward per episode: -164.52
# Num timesteps: 60000
# Best mean reward: -145.95 - Last mean reward per episode: -170.11
# Num timesteps: 61000
# Best mean reward: -145.95 - Last mean reward per episode: -168.51
# Num timesteps: 62000
# Best mean reward: -145.95 - Last mean reward per episode: -169.25
# Num timesteps: 63000
# Best mean reward: -145.95 - Last mean reward per episode: -168.58
# Num timesteps: 64000
# Best mean reward: -145.95 - Last mean reward per episode: -172.32
# Num timesteps: 65000
# Best mean reward: -145.95 - Last mean reward per episode: -173.16
# Num timesteps: 66000
# Best mean reward: -145.95 - Last mean reward per episode: -177.20
# Num timesteps: 67000
# Best mean reward: -145.95 - Last mean reward per episode: -176.66
# Num timesteps: 68000
# Best mean reward: -145.95 - Last mean reward per episode: -175.75
# Num timesteps: 69000
# Best mean reward: -145.95 - Last mean reward per episode: -172.82
# Num timesteps: 70000
# Best mean reward: -145.95 - Last mean reward per episode: -174.26
# Num timesteps: 71000
# Best mean reward: -145.95 - Last mean reward per episode: -176.18
# Num timesteps: 72000
# Best mean reward: -145.95 - Last mean reward per episode: -170.80
# Num timesteps: 73000
# Best mean reward: -145.95 - Last mean reward per episode: -164.40
# Num timesteps: 74000
# Best mean reward: -145.95 - Last mean reward per episode: -161.94
# Num timesteps: 75000
# Best mean reward: -145.95 - Last mean reward per episode: -162.76
# Num timesteps: 76000
# Best mean reward: -145.95 - Last mean reward per episode: -162.53
# Num timesteps: 77000
# Best mean reward: -145.95 - Last mean reward per episode: -161.41
# Num timesteps: 78000
# Best mean reward: -145.95 - Last mean reward per episode: -155.34
# Num timesteps: 79000
# Best mean reward: -145.95 - Last mean reward per episode: -158.66
# Num timesteps: 80000
# Best mean reward: -145.95 - Last mean reward per episode: -154.61
# Num timesteps: 81000
# Best mean reward: -145.95 - Last mean reward per episode: -157.79
# Num timesteps: 82000
# Best mean reward: -145.95 - Last mean reward per episode: -158.68
# Num timesteps: 83000
# Best mean reward: -145.95 - Last mean reward per episode: -162.60
# Num timesteps: 84000
# Best mean reward: -145.95 - Last mean reward per episode: -159.80
# Num timesteps: 85000
# Best mean reward: -145.95 - Last mean reward per episode: -154.93
# Num timesteps: 86000
# Best mean reward: -145.95 - Last mean reward per episode: -151.29
# Num timesteps: 87000
# Best mean reward: -145.95 - Last mean reward per episode: -152.53
# Num timesteps: 88000
# Best mean reward: -145.95 - Last mean reward per episode: -147.30
# Num timesteps: 89000
# Best mean reward: -145.95 - Last mean reward per episode: -148.55
# Num timesteps: 90000
# Best mean reward: -145.95 - Last mean reward per episode: -146.44
# Num timesteps: 91000
# Best mean reward: -145.95 - Last mean reward per episode: -143.01
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 92000
# Best mean reward: -143.01 - Last mean reward per episode: -147.59
# Num timesteps: 93000
# Best mean reward: -143.01 - Last mean reward per episode: -152.57
# Num timesteps: 94000
# Best mean reward: -143.01 - Last mean reward per episode: -150.21
# Num timesteps: 95000
# Best mean reward: -143.01 - Last mean reward per episode: -148.00
# Num timesteps: 96000
# Best mean reward: -143.01 - Last mean reward per episode: -149.29
# Num timesteps: 97000
# Best mean reward: -143.01 - Last mean reward per episode: -149.74
# Num timesteps: 98000
# Best mean reward: -143.01 - Last mean reward per episode: -148.74
# Num timesteps: 99000
# Best mean reward: -143.01 - Last mean reward per episode: -148.59
# Num timesteps: 100000
# Best mean reward: -143.01 - Last mean reward per episode: -145.36
# Num timesteps: 101000
# Best mean reward: -143.01 - Last mean reward per episode: -139.85
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 102000
# Best mean reward: -139.85 - Last mean reward per episode: -137.85
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 103000
# Best mean reward: -137.85 - Last mean reward per episode: -139.09
# Num timesteps: 104000
# Best mean reward: -137.85 - Last mean reward per episode: -135.63
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 105000
# Best mean reward: -135.63 - Last mean reward per episode: -134.52
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 106000
# Best mean reward: -134.52 - Last mean reward per episode: -135.61
# Num timesteps: 107000
# Best mean reward: -134.52 - Last mean reward per episode: -132.17
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 108000
# Best mean reward: -132.17 - Last mean reward per episode: -135.59
# Num timesteps: 109000
# Best mean reward: -132.17 - Last mean reward per episode: -136.47
# Num timesteps: 110000
# Best mean reward: -132.17 - Last mean reward per episode: -138.69
# Num timesteps: 111000
# Best mean reward: -132.17 - Last mean reward per episode: -143.04
# Num timesteps: 112000
# Best mean reward: -132.17 - Last mean reward per episode: -140.75
# Num timesteps: 113000
# Best mean reward: -132.17 - Last mean reward per episode: -138.06
# Num timesteps: 114000
# Best mean reward: -132.17 - Last mean reward per episode: -141.63
# Num timesteps: 115000
# Best mean reward: -132.17 - Last mean reward per episode: -144.99
# Num timesteps: 116000
# Best mean reward: -132.17 - Last mean reward per episode: -142.64
# Num timesteps: 117000
# Best mean reward: -132.17 - Last mean reward per episode: -140.84
# Num timesteps: 118000
# Best mean reward: -132.17 - Last mean reward per episode: -144.06
# Num timesteps: 119000
# Best mean reward: -132.17 - Last mean reward per episode: -138.53
# Num timesteps: 120000
# Best mean reward: -132.17 - Last mean reward per episode: -146.02
# Num timesteps: 121000
# Best mean reward: -132.17 - Last mean reward per episode: -151.94
# Num timesteps: 122000
# Best mean reward: -132.17 - Last mean reward per episode: -150.83
# Num timesteps: 123000
# Best mean reward: -132.17 - Last mean reward per episode: -150.78
# Num timesteps: 124000
# Best mean reward: -132.17 - Last mean reward per episode: -154.24
# Num timesteps: 125000
# Best mean reward: -132.17 - Last mean reward per episode: -154.01
# Num timesteps: 126000
# Best mean reward: -132.17 - Last mean reward per episode: -153.07
# Num timesteps: 127000
# Best mean reward: -132.17 - Last mean reward per episode: -156.37
# Num timesteps: 128000
# Best mean reward: -132.17 - Last mean reward per episode: -156.38
# Num timesteps: 129000
# Best mean reward: -132.17 - Last mean reward per episode: -155.73
# Num timesteps: 130000
# Best mean reward: -132.17 - Last mean reward per episode: -155.94
# Num timesteps: 131000
# Best mean reward: -132.17 - Last mean reward per episode: -155.89
# Num timesteps: 132000
# Best mean reward: -132.17 - Last mean reward per episode: -154.85
# Num timesteps: 133000
# Best mean reward: -132.17 - Last mean reward per episode: -152.57
# Num timesteps: 134000
# Best mean reward: -132.17 - Last mean reward per episode: -150.41
# Num timesteps: 135000
# Best mean reward: -132.17 - Last mean reward per episode: -151.45
# Num timesteps: 136000
# Best mean reward: -132.17 - Last mean reward per episode: -153.75
# Num timesteps: 137000
# Best mean reward: -132.17 - Last mean reward per episode: -155.56
# Num timesteps: 138000
# Best mean reward: -132.17 - Last mean reward per episode: -154.79
# Num timesteps: 139000
# Best mean reward: -132.17 - Last mean reward per episode: -155.99
# Num timesteps: 140000
# Best mean reward: -132.17 - Last mean reward per episode: -153.03
# Num timesteps: 141000
# Best mean reward: -132.17 - Last mean reward per episode: -156.04
# Num timesteps: 142000
# Best mean reward: -132.17 - Last mean reward per episode: -157.44
# Num timesteps: 143000
# Best mean reward: -132.17 - Last mean reward per episode: -158.74
# Num timesteps: 144000
# Best mean reward: -132.17 - Last mean reward per episode: -154.23
# Num timesteps: 145000
# Best mean reward: -132.17 - Last mean reward per episode: -159.53
# Num timesteps: 146000
# Best mean reward: -132.17 - Last mean reward per episode: -160.90
# Num timesteps: 147000
# Best mean reward: -132.17 - Last mean reward per episode: -159.98
# Num timesteps: 148000
# Best mean reward: -132.17 - Last mean reward per episode: -157.69
# Num timesteps: 149000
# Best mean reward: -132.17 - Last mean reward per episode: -159.18
# Num timesteps: 150000
# Best mean reward: -132.17 - Last mean reward per episode: -157.87
# Num timesteps: 151000
# Best mean reward: -132.17 - Last mean reward per episode: -154.67
# Num timesteps: 152000
# Best mean reward: -132.17 - Last mean reward per episode: -155.33
# Num timesteps: 153000
# Best mean reward: -132.17 - Last mean reward per episode: -160.11
# Num timesteps: 154000
# Best mean reward: -132.17 - Last mean reward per episode: -162.39
# Num timesteps: 155000
# Best mean reward: -132.17 - Last mean reward per episode: -161.13
# Num timesteps: 156000
# Best mean reward: -132.17 - Last mean reward per episode: -158.61
# Num timesteps: 157000
# Best mean reward: -132.17 - Last mean reward per episode: -155.84
# Num timesteps: 158000
# Best mean reward: -132.17 - Last mean reward per episode: -155.50
# Num timesteps: 159000
# Best mean reward: -132.17 - Last mean reward per episode: -156.26
# Num timesteps: 160000
# Best mean reward: -132.17 - Last mean reward per episode: -152.74
# Num timesteps: 161000
# Best mean reward: -132.17 - Last mean reward per episode: -148.48
# Num timesteps: 162000
# Best mean reward: -132.17 - Last mean reward per episode: -147.28
# Num timesteps: 163000
# Best mean reward: -132.17 - Last mean reward per episode: -141.11
# Num timesteps: 164000
# Best mean reward: -132.17 - Last mean reward per episode: -143.27
# Num timesteps: 165000
# Best mean reward: -132.17 - Last mean reward per episode: -140.90
# Num timesteps: 166000
# Best mean reward: -132.17 - Last mean reward per episode: -140.50
# Num timesteps: 167000
# Best mean reward: -132.17 - Last mean reward per episode: -138.20
# Num timesteps: 168000
# Best mean reward: -132.17 - Last mean reward per episode: -140.58
# Num timesteps: 169000
# Best mean reward: -132.17 - Last mean reward per episode: -140.13
# Num timesteps: 170000
# Best mean reward: -132.17 - Last mean reward per episode: -142.40
# Num timesteps: 171000
# Best mean reward: -132.17 - Last mean reward per episode: -144.56
# Num timesteps: 172000
# Best mean reward: -132.17 - Last mean reward per episode: -144.92
# Num timesteps: 173000
# Best mean reward: -132.17 - Last mean reward per episode: -145.15
# Num timesteps: 174000
# Best mean reward: -132.17 - Last mean reward per episode: -143.92
# Num timesteps: 175000
# Best mean reward: -132.17 - Last mean reward per episode: -140.76
# Num timesteps: 176000
# Best mean reward: -132.17 - Last mean reward per episode: -139.84
# Num timesteps: 177000
# Best mean reward: -132.17 - Last mean reward per episode: -146.84
# Num timesteps: 178000
# Best mean reward: -132.17 - Last mean reward per episode: -149.60
# Num timesteps: 179000
# Best mean reward: -132.17 - Last mean reward per episode: -150.06
# Num timesteps: 180000
# Best mean reward: -132.17 - Last mean reward per episode: -153.71
# Num timesteps: 181000
# Best mean reward: -132.17 - Last mean reward per episode: -152.55
# Num timesteps: 182000
# Best mean reward: -132.17 - Last mean reward per episode: -156.02
# Num timesteps: 183000
# Best mean reward: -132.17 - Last mean reward per episode: -160.01
# Num timesteps: 184000
# Best mean reward: -132.17 - Last mean reward per episode: -161.49
# Num timesteps: 185000
# Best mean reward: -132.17 - Last mean reward per episode: -165.52
# Num timesteps: 186000
# Best mean reward: -132.17 - Last mean reward per episode: -166.78
# Num timesteps: 187000
# Best mean reward: -132.17 - Last mean reward per episode: -170.18
# Num timesteps: 188000
# Best mean reward: -132.17 - Last mean reward per episode: -173.36
# Num timesteps: 189000
# Best mean reward: -132.17 - Last mean reward per episode: -173.00
# Num timesteps: 190000
# Best mean reward: -132.17 - Last mean reward per episode: -169.52
# Num timesteps: 191000
# Best mean reward: -132.17 - Last mean reward per episode: -168.33
# Num timesteps: 192000
# Best mean reward: -132.17 - Last mean reward per episode: -167.50
# Num timesteps: 193000
# Best mean reward: -132.17 - Last mean reward per episode: -163.64
# Num timesteps: 194000
# Best mean reward: -132.17 - Last mean reward per episode: -165.83
# Num timesteps: 195000
# Best mean reward: -132.17 - Last mean reward per episode: -168.20
# Num timesteps: 196000
# Best mean reward: -132.17 - Last mean reward per episode: -166.93
# Num timesteps: 197000
# Best mean reward: -132.17 - Last mean reward per episode: -162.03
# Num timesteps: 198000
# Best mean reward: -132.17 - Last mean reward per episode: -156.08
# Num timesteps: 199000
# Best mean reward: -132.17 - Last mean reward per episode: -153.97
# Num timesteps: 200000
# Best mean reward: -132.17 - Last mean reward per episode: -156.07

# %%
# Plotting

def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, 'valid')


def plot_results(log_folder, title='Learning Curve'):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    
    x, y = ts2xy(load_results(log_folder), 'timesteps')

    y_mean = moving_average(y, window=50)
    # Truncate x
    x_mean = x[len(x) - len(y_mean):]

    fig = plt.figure(title)
    plt.plot(x, y, alpha=0.4, label="Rewards")
    plt.plot(x_mean, y_mean, label="Mean rewards - wd:50")
    plt.xlabel('Number of Timesteps')
    plt.ylabel('Rewards')
    plt.title(title)
    plt.legend(loc="best")
    plt.show()


plot_results(log_dir)

# %%
# Test 

scores = []
for i in range(100):
    obs = env.reset()
    score = 0
    done = False
    
    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        score += reward
    
    scores.append(score)

np.mean(scores)
# Out:
# -135.19860470204227
