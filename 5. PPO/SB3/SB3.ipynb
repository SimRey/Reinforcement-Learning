# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import PPO
from stable_baselines3.common import results_plotter
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback

# This part allows the graph to be drawn
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), 'timesteps')
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose > 0:
                print(f"Num timesteps: {self.num_timesteps}")
                print(f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}")

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose > 0:
                    print(f"Saving new best model to {self.save_path}.zip")
                  self.model.save(self.save_path)

        return True

# %%
# Create and wrap the environment

# Create log dir
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = gym.make("Pendulum-v0")

# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)
# Out:
# c:\Users\Lenovo\anaconda3\envs\myenv\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
# Create and train the agent

# Create the callback: check every 1000 steps
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)
# Create RL model
model = PPO("MlpPolicy", env)
# Train the agent
model.learn(total_timesteps=int(500e3), callback=callback)
# Out:
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -1207.73
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 2000
# Best mean reward: -1207.73 - Last mean reward per episode: -1236.28
# Num timesteps: 3000
# Best mean reward: -1207.73 - Last mean reward per episode: -1216.28
# Num timesteps: 4000
# Best mean reward: -1207.73 - Last mean reward per episode: -1201.23
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 5000
# Best mean reward: -1201.23 - Last mean reward per episode: -1202.56
# Num timesteps: 6000
# Best mean reward: -1201.23 - Last mean reward per episode: -1192.03
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 7000
# Best mean reward: -1192.03 - Last mean reward per episode: -1174.33
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 8000
# Best mean reward: -1174.33 - Last mean reward per episode: -1172.62
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 9000
# Best mean reward: -1172.62 - Last mean reward per episode: -1184.80
# Num timesteps: 10000
# Best mean reward: -1172.62 - Last mean reward per episode: -1182.92
# Num timesteps: 11000
# Best mean reward: -1172.62 - Last mean reward per episode: -1161.78
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 12000
# Best mean reward: -1161.78 - Last mean reward per episode: -1158.15
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 13000
# Best mean reward: -1158.15 - Last mean reward per episode: -1155.08
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 14000
# Best mean reward: -1155.08 - Last mean reward per episode: -1158.15
# Num timesteps: 15000
# Best mean reward: -1155.08 - Last mean reward per episode: -1161.56
# Num timesteps: 16000
# Best mean reward: -1155.08 - Last mean reward per episode: -1155.74
# Num timesteps: 17000
# Best mean reward: -1155.08 - Last mean reward per episode: -1166.19
# Num timesteps: 18000
# Best mean reward: -1155.08 - Last mean reward per episode: -1162.70
# Num timesteps: 19000
# Best mean reward: -1155.08 - Last mean reward per episode: -1172.44
# Num timesteps: 20000
# Best mean reward: -1155.08 - Last mean reward per episode: -1162.87
# Num timesteps: 21000
# Best mean reward: -1155.08 - Last mean reward per episode: -1169.95
# Num timesteps: 22000
# Best mean reward: -1155.08 - Last mean reward per episode: -1156.24
# Num timesteps: 23000
# Best mean reward: -1155.08 - Last mean reward per episode: -1159.07
# Num timesteps: 24000
# Best mean reward: -1155.08 - Last mean reward per episode: -1167.41
# Num timesteps: 25000
# Best mean reward: -1155.08 - Last mean reward per episode: -1168.65
# Num timesteps: 26000
# Best mean reward: -1155.08 - Last mean reward per episode: -1160.86
# Num timesteps: 27000
# Best mean reward: -1155.08 - Last mean reward per episode: -1172.58
# Num timesteps: 28000
# Best mean reward: -1155.08 - Last mean reward per episode: -1179.44
# Num timesteps: 29000
# Best mean reward: -1155.08 - Last mean reward per episode: -1177.32
# Num timesteps: 30000
# Best mean reward: -1155.08 - Last mean reward per episode: -1174.63
# Num timesteps: 31000
# Best mean reward: -1155.08 - Last mean reward per episode: -1182.95
# Num timesteps: 32000
# Best mean reward: -1155.08 - Last mean reward per episode: -1184.08
# Num timesteps: 33000
# Best mean reward: -1155.08 - Last mean reward per episode: -1184.96
# Num timesteps: 34000
# Best mean reward: -1155.08 - Last mean reward per episode: -1179.57
# Num timesteps: 35000
# Best mean reward: -1155.08 - Last mean reward per episode: -1177.00
# Num timesteps: 36000
# Best mean reward: -1155.08 - Last mean reward per episode: -1181.08
# Num timesteps: 37000
# Best mean reward: -1155.08 - Last mean reward per episode: -1176.29
# Num timesteps: 38000
# Best mean reward: -1155.08 - Last mean reward per episode: -1182.31
# Num timesteps: 39000
# Best mean reward: -1155.08 - Last mean reward per episode: -1183.63
# Num timesteps: 40000
# Best mean reward: -1155.08 - Last mean reward per episode: -1188.78
# Num timesteps: 41000
# Best mean reward: -1155.08 - Last mean reward per episode: -1179.52
# Num timesteps: 42000
# Best mean reward: -1155.08 - Last mean reward per episode: -1198.38
# Num timesteps: 43000
# Best mean reward: -1155.08 - Last mean reward per episode: -1201.05
# Num timesteps: 44000
# Best mean reward: -1155.08 - Last mean reward per episode: -1193.65
# Num timesteps: 45000
# Best mean reward: -1155.08 - Last mean reward per episode: -1182.32
# Num timesteps: 46000
# Best mean reward: -1155.08 - Last mean reward per episode: -1192.49
# Num timesteps: 47000
# Best mean reward: -1155.08 - Last mean reward per episode: -1183.19
# Num timesteps: 48000
# Best mean reward: -1155.08 - Last mean reward per episode: -1166.42
# Num timesteps: 49000
# Best mean reward: -1155.08 - Last mean reward per episode: -1166.88
# Num timesteps: 50000
# Best mean reward: -1155.08 - Last mean reward per episode: -1169.51
# Num timesteps: 51000
# Best mean reward: -1155.08 - Last mean reward per episode: -1172.74
# Num timesteps: 52000
# Best mean reward: -1155.08 - Last mean reward per episode: -1171.91
# Num timesteps: 53000
# Best mean reward: -1155.08 - Last mean reward per episode: -1165.23
# Num timesteps: 54000
# Best mean reward: -1155.08 - Last mean reward per episode: -1158.33
# Num timesteps: 55000
# Best mean reward: -1155.08 - Last mean reward per episode: -1155.39
# Num timesteps: 56000
# Best mean reward: -1155.08 - Last mean reward per episode: -1155.18
# Num timesteps: 57000
# Best mean reward: -1155.08 - Last mean reward per episode: -1143.46
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 58000
# Best mean reward: -1143.46 - Last mean reward per episode: -1135.76
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 59000
# Best mean reward: -1135.76 - Last mean reward per episode: -1117.71
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 60000
# Best mean reward: -1117.71 - Last mean reward per episode: -1116.24
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 61000
# Best mean reward: -1116.24 - Last mean reward per episode: -1106.60
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 62000
# Best mean reward: -1106.60 - Last mean reward per episode: -1089.62
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 63000
# Best mean reward: -1089.62 - Last mean reward per episode: -1075.53
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 64000
# Best mean reward: -1075.53 - Last mean reward per episode: -1078.20
# Num timesteps: 65000
# Best mean reward: -1075.53 - Last mean reward per episode: -1081.36
# Num timesteps: 66000
# Best mean reward: -1075.53 - Last mean reward per episode: -1075.26
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 67000
# Best mean reward: -1075.26 - Last mean reward per episode: -1074.15
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 68000
# Best mean reward: -1074.15 - Last mean reward per episode: -1073.81
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 69000
# Best mean reward: -1073.81 - Last mean reward per episode: -1063.06
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 70000
# Best mean reward: -1063.06 - Last mean reward per episode: -1050.05
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 71000
# Best mean reward: -1050.05 - Last mean reward per episode: -1046.86
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 72000
# Best mean reward: -1046.86 - Last mean reward per episode: -1044.98
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 73000
# Best mean reward: -1044.98 - Last mean reward per episode: -1041.18
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 74000
# Best mean reward: -1041.18 - Last mean reward per episode: -1038.80
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 75000
# Best mean reward: -1038.80 - Last mean reward per episode: -1032.96
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 76000
# Best mean reward: -1032.96 - Last mean reward per episode: -1027.97
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 77000
# Best mean reward: -1027.97 - Last mean reward per episode: -1024.42
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 78000
# Best mean reward: -1024.42 - Last mean reward per episode: -1023.57
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 79000
# Best mean reward: -1023.57 - Last mean reward per episode: -1025.15
# Num timesteps: 80000
# Best mean reward: -1023.57 - Last mean reward per episode: -1021.44
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 81000
# Best mean reward: -1021.44 - Last mean reward per episode: -1014.61
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 82000
# Best mean reward: -1014.61 - Last mean reward per episode: -1012.89
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 83000
# Best mean reward: -1012.89 - Last mean reward per episode: -1008.36
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 84000
# Best mean reward: -1008.36 - Last mean reward per episode: -1001.85
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 85000
# Best mean reward: -1001.85 - Last mean reward per episode: -996.71
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 86000
# Best mean reward: -996.71 - Last mean reward per episode: -988.01
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 87000
# Best mean reward: -988.01 - Last mean reward per episode: -987.83
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 88000
# Best mean reward: -987.83 - Last mean reward per episode: -987.25
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 89000
# Best mean reward: -987.25 - Last mean reward per episode: -987.96
# Num timesteps: 90000
# Best mean reward: -987.25 - Last mean reward per episode: -990.59
# Num timesteps: 91000
# Best mean reward: -987.25 - Last mean reward per episode: -982.34
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 92000
# Best mean reward: -982.34 - Last mean reward per episode: -974.12
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 93000
# Best mean reward: -974.12 - Last mean reward per episode: -978.08
# Num timesteps: 94000
# Best mean reward: -974.12 - Last mean reward per episode: -984.52
# Num timesteps: 95000
# Best mean reward: -974.12 - Last mean reward per episode: -979.59
# Num timesteps: 96000
# Best mean reward: -974.12 - Last mean reward per episode: -977.58
# Num timesteps: 97000
# Best mean reward: -974.12 - Last mean reward per episode: -976.43
# Num timesteps: 98000
# Best mean reward: -974.12 - Last mean reward per episode: -967.51
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 99000
# Best mean reward: -967.51 - Last mean reward per episode: -968.85
# Num timesteps: 100000
# Best mean reward: -967.51 - Last mean reward per episode: -968.77
# Num timesteps: 101000
# Best mean reward: -967.51 - Last mean reward per episode: -974.44
# Num timesteps: 102000
# Best mean reward: -967.51 - Last mean reward per episode: -973.77
# Num timesteps: 103000
# Best mean reward: -967.51 - Last mean reward per episode: -974.40
# Num timesteps: 104000
# Best mean reward: -967.51 - Last mean reward per episode: -973.55
# Num timesteps: 105000
# Best mean reward: -967.51 - Last mean reward per episode: -976.06
# Num timesteps: 106000
# Best mean reward: -967.51 - Last mean reward per episode: -981.42
# Num timesteps: 107000
# Best mean reward: -967.51 - Last mean reward per episode: -975.41
# Num timesteps: 108000
# Best mean reward: -967.51 - Last mean reward per episode: -975.39
# Num timesteps: 109000
# Best mean reward: -967.51 - Last mean reward per episode: -968.98
# Num timesteps: 110000
# Best mean reward: -967.51 - Last mean reward per episode: -967.99
# Num timesteps: 111000
# Best mean reward: -967.51 - Last mean reward per episode: -967.81
# Num timesteps: 112000
# Best mean reward: -967.51 - Last mean reward per episode: -968.74
# Num timesteps: 113000
# Best mean reward: -967.51 - Last mean reward per episode: -964.63
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 114000
# Best mean reward: -964.63 - Last mean reward per episode: -959.85
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 115000
# Best mean reward: -959.85 - Last mean reward per episode: -959.92
# Num timesteps: 116000
# Best mean reward: -959.85 - Last mean reward per episode: -953.96
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 117000
# Best mean reward: -953.96 - Last mean reward per episode: -954.83
# Num timesteps: 118000
# Best mean reward: -953.96 - Last mean reward per episode: -962.49
# Num timesteps: 119000
# Best mean reward: -953.96 - Last mean reward per episode: -960.86
# Num timesteps: 120000
# Best mean reward: -953.96 - Last mean reward per episode: -971.26
# Num timesteps: 121000
# Best mean reward: -953.96 - Last mean reward per episode: -973.18
# Num timesteps: 122000
# Best mean reward: -953.96 - Last mean reward per episode: -975.56
# Num timesteps: 123000
# Best mean reward: -953.96 - Last mean reward per episode: -979.66
# Num timesteps: 124000
# Best mean reward: -953.96 - Last mean reward per episode: -964.03
# Num timesteps: 125000
# Best mean reward: -953.96 - Last mean reward per episode: -963.21
# Num timesteps: 126000
# Best mean reward: -953.96 - Last mean reward per episode: -964.66
# Num timesteps: 127000
# Best mean reward: -953.96 - Last mean reward per episode: -960.38
# Num timesteps: 128000
# Best mean reward: -953.96 - Last mean reward per episode: -966.24
# Num timesteps: 129000
# Best mean reward: -953.96 - Last mean reward per episode: -969.12
# Num timesteps: 130000
# Best mean reward: -953.96 - Last mean reward per episode: -964.32
# Num timesteps: 131000
# Best mean reward: -953.96 - Last mean reward per episode: -954.90
# Num timesteps: 132000
# Best mean reward: -953.96 - Last mean reward per episode: -955.44
# Num timesteps: 133000
# Best mean reward: -953.96 - Last mean reward per episode: -955.33
# Num timesteps: 134000
# Best mean reward: -953.96 - Last mean reward per episode: -956.26
# Num timesteps: 135000
# Best mean reward: -953.96 - Last mean reward per episode: -962.72
# Num timesteps: 136000
# Best mean reward: -953.96 - Last mean reward per episode: -968.81
# Num timesteps: 137000
# Best mean reward: -953.96 - Last mean reward per episode: -968.64
# Num timesteps: 138000
# Best mean reward: -953.96 - Last mean reward per episode: -966.53
# Num timesteps: 139000
# Best mean reward: -953.96 - Last mean reward per episode: -964.22
# Num timesteps: 140000
# Best mean reward: -953.96 - Last mean reward per episode: -951.83
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 141000
# Best mean reward: -951.83 - Last mean reward per episode: -952.64
# Num timesteps: 142000
# Best mean reward: -951.83 - Last mean reward per episode: -951.76
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 143000
# Best mean reward: -951.76 - Last mean reward per episode: -945.45
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 144000
# Best mean reward: -945.45 - Last mean reward per episode: -954.62
# Num timesteps: 145000
# Best mean reward: -945.45 - Last mean reward per episode: -948.89
# Num timesteps: 146000
# Best mean reward: -945.45 - Last mean reward per episode: -942.24
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 147000
# Best mean reward: -942.24 - Last mean reward per episode: -945.62
# Num timesteps: 148000
# Best mean reward: -942.24 - Last mean reward per episode: -937.03
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 149000
# Best mean reward: -937.03 - Last mean reward per episode: -935.21
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 150000
# Best mean reward: -935.21 - Last mean reward per episode: -937.32
# Num timesteps: 151000
# Best mean reward: -935.21 - Last mean reward per episode: -953.53
# Num timesteps: 152000
# Best mean reward: -935.21 - Last mean reward per episode: -960.73
# Num timesteps: 153000
# Best mean reward: -935.21 - Last mean reward per episode: -965.31
# Num timesteps: 154000
# Best mean reward: -935.21 - Last mean reward per episode: -962.09
# Num timesteps: 155000
# Best mean reward: -935.21 - Last mean reward per episode: -969.22
# Num timesteps: 156000
# Best mean reward: -935.21 - Last mean reward per episode: -972.34
# Num timesteps: 157000
# Best mean reward: -935.21 - Last mean reward per episode: -966.53
# Num timesteps: 158000
# Best mean reward: -935.21 - Last mean reward per episode: -951.76
# Num timesteps: 159000
# Best mean reward: -935.21 - Last mean reward per episode: -946.75
# Num timesteps: 160000
# Best mean reward: -935.21 - Last mean reward per episode: -952.00
# Num timesteps: 161000
# Best mean reward: -935.21 - Last mean reward per episode: -944.44
# Num timesteps: 162000
# Best mean reward: -935.21 - Last mean reward per episode: -939.67
# Num timesteps: 163000
# Best mean reward: -935.21 - Last mean reward per episode: -944.99
# Num timesteps: 164000
# Best mean reward: -935.21 - Last mean reward per episode: -944.06
# Num timesteps: 165000
# Best mean reward: -935.21 - Last mean reward per episode: -946.96
# Num timesteps: 166000
# Best mean reward: -935.21 - Last mean reward per episode: -955.91
# Num timesteps: 167000
# Best mean reward: -935.21 - Last mean reward per episode: -957.05
# Num timesteps: 168000
# Best mean reward: -935.21 - Last mean reward per episode: -962.39
# Num timesteps: 169000
# Best mean reward: -935.21 - Last mean reward per episode: -950.14
# Num timesteps: 170000
# Best mean reward: -935.21 - Last mean reward per episode: -945.73
# Num timesteps: 171000
# Best mean reward: -935.21 - Last mean reward per episode: -930.59
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 172000
# Best mean reward: -930.59 - Last mean reward per episode: -924.93
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 173000
# Best mean reward: -924.93 - Last mean reward per episode: -932.28
# Num timesteps: 174000
# Best mean reward: -924.93 - Last mean reward per episode: -942.35
# Num timesteps: 175000
# Best mean reward: -924.93 - Last mean reward per episode: -937.06
# Num timesteps: 176000
# Best mean reward: -924.93 - Last mean reward per episode: -921.52
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 177000
# Best mean reward: -921.52 - Last mean reward per episode: -920.85
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 178000
# Best mean reward: -920.85 - Last mean reward per episode: -937.32
# Num timesteps: 179000
# Best mean reward: -920.85 - Last mean reward per episode: -930.91
# Num timesteps: 180000
# Best mean reward: -920.85 - Last mean reward per episode: -910.61
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 181000
# Best mean reward: -910.61 - Last mean reward per episode: -904.52
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 182000
# Best mean reward: -904.52 - Last mean reward per episode: -882.86
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 183000
# Best mean reward: -882.86 - Last mean reward per episode: -863.73
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 184000
# Best mean reward: -863.73 - Last mean reward per episode: -847.15
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 185000
# Best mean reward: -847.15 - Last mean reward per episode: -835.03
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 186000
# Best mean reward: -835.03 - Last mean reward per episode: -818.42
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 187000
# Best mean reward: -818.42 - Last mean reward per episode: -789.14
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 188000
# Best mean reward: -789.14 - Last mean reward per episode: -761.05
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 189000
# Best mean reward: -761.05 - Last mean reward per episode: -770.33
# Num timesteps: 190000
# Best mean reward: -761.05 - Last mean reward per episode: -760.32
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 191000
# Best mean reward: -760.32 - Last mean reward per episode: -734.28
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 192000
# Best mean reward: -734.28 - Last mean reward per episode: -722.90
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 193000
# Best mean reward: -722.90 - Last mean reward per episode: -684.35
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 194000
# Best mean reward: -684.35 - Last mean reward per episode: -656.97
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 195000
# Best mean reward: -656.97 - Last mean reward per episode: -652.04
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 196000
# Best mean reward: -652.04 - Last mean reward per episode: -631.36
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 197000
# Best mean reward: -631.36 - Last mean reward per episode: -606.09
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 198000
# Best mean reward: -606.09 - Last mean reward per episode: -576.79
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 199000
# Best mean reward: -576.79 - Last mean reward per episode: -562.01
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 200000
# Best mean reward: -562.01 - Last mean reward per episode: -543.11
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 201000
# Best mean reward: -543.11 - Last mean reward per episode: -534.76
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 202000
# Best mean reward: -534.76 - Last mean reward per episode: -526.52
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 203000
# Best mean reward: -526.52 - Last mean reward per episode: -523.95
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 204000
# Best mean reward: -523.95 - Last mean reward per episode: -529.37
# Num timesteps: 205000
# Best mean reward: -523.95 - Last mean reward per episode: -521.19
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 206000
# Best mean reward: -521.19 - Last mean reward per episode: -500.86
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 207000
# Best mean reward: -500.86 - Last mean reward per episode: -523.08
# Num timesteps: 208000
# Best mean reward: -500.86 - Last mean reward per episode: -542.39
# Num timesteps: 209000
# Best mean reward: -500.86 - Last mean reward per episode: -534.66
# Num timesteps: 210000
# Best mean reward: -500.86 - Last mean reward per episode: -533.65
# Num timesteps: 211000
# Best mean reward: -500.86 - Last mean reward per episode: -544.83
# Num timesteps: 212000
# Best mean reward: -500.86 - Last mean reward per episode: -520.21
# Num timesteps: 213000
# Best mean reward: -500.86 - Last mean reward per episode: -527.59
# Num timesteps: 214000
# Best mean reward: -500.86 - Last mean reward per episode: -516.11
# Num timesteps: 215000
# Best mean reward: -500.86 - Last mean reward per episode: -494.92
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 216000
# Best mean reward: -494.92 - Last mean reward per episode: -511.74
# Num timesteps: 217000
# Best mean reward: -494.92 - Last mean reward per episode: -514.22
# Num timesteps: 218000
# Best mean reward: -494.92 - Last mean reward per episode: -530.82
# Num timesteps: 219000
# Best mean reward: -494.92 - Last mean reward per episode: -528.40
# Num timesteps: 220000
# Best mean reward: -494.92 - Last mean reward per episode: -557.15
# Num timesteps: 221000
# Best mean reward: -494.92 - Last mean reward per episode: -550.12
# Num timesteps: 222000
# Best mean reward: -494.92 - Last mean reward per episode: -559.93
# Num timesteps: 223000
# Best mean reward: -494.92 - Last mean reward per episode: -551.61
# Num timesteps: 224000
# Best mean reward: -494.92 - Last mean reward per episode: -536.62
# Num timesteps: 225000
# Best mean reward: -494.92 - Last mean reward per episode: -529.74
# Num timesteps: 226000
# Best mean reward: -494.92 - Last mean reward per episode: -548.44
# Num timesteps: 227000
# Best mean reward: -494.92 - Last mean reward per episode: -523.58
# Num timesteps: 228000
# Best mean reward: -494.92 - Last mean reward per episode: -505.60
# Num timesteps: 229000
# Best mean reward: -494.92 - Last mean reward per episode: -489.94
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 230000
# Best mean reward: -489.94 - Last mean reward per episode: -484.88
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 231000
# Best mean reward: -484.88 - Last mean reward per episode: -485.69
# Num timesteps: 232000
# Best mean reward: -484.88 - Last mean reward per episode: -485.59
# Num timesteps: 233000
# Best mean reward: -484.88 - Last mean reward per episode: -468.94
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 234000
# Best mean reward: -468.94 - Last mean reward per episode: -472.84
# Num timesteps: 235000
# Best mean reward: -468.94 - Last mean reward per episode: -471.20
# Num timesteps: 236000
# Best mean reward: -468.94 - Last mean reward per episode: -452.80
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 237000
# Best mean reward: -452.80 - Last mean reward per episode: -451.71
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 238000
# Best mean reward: -451.71 - Last mean reward per episode: -428.54
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 239000
# Best mean reward: -428.54 - Last mean reward per episode: -424.61
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 240000
# Best mean reward: -424.61 - Last mean reward per episode: -406.73
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 241000
# Best mean reward: -406.73 - Last mean reward per episode: -397.45
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 242000
# Best mean reward: -397.45 - Last mean reward per episode: -380.80
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 243000
# Best mean reward: -380.80 - Last mean reward per episode: -379.06
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 244000
# Best mean reward: -379.06 - Last mean reward per episode: -368.93
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 245000
# Best mean reward: -368.93 - Last mean reward per episode: -376.17
# Num timesteps: 246000
# Best mean reward: -368.93 - Last mean reward per episode: -355.52
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 247000
# Best mean reward: -355.52 - Last mean reward per episode: -356.22
# Num timesteps: 248000
# Best mean reward: -355.52 - Last mean reward per episode: -361.85
# Num timesteps: 249000
# Best mean reward: -355.52 - Last mean reward per episode: -354.22
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 250000
# Best mean reward: -354.22 - Last mean reward per episode: -361.92
# Num timesteps: 251000
# Best mean reward: -354.22 - Last mean reward per episode: -354.19
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 252000
# Best mean reward: -354.19 - Last mean reward per episode: -365.38
# Num timesteps: 253000
# Best mean reward: -354.19 - Last mean reward per episode: -377.33
# Num timesteps: 254000
# Best mean reward: -354.19 - Last mean reward per episode: -385.87
# Num timesteps: 255000
# Best mean reward: -354.19 - Last mean reward per episode: -377.37
# Num timesteps: 256000
# Best mean reward: -354.19 - Last mean reward per episode: -374.06
# Num timesteps: 257000
# Best mean reward: -354.19 - Last mean reward per episode: -379.36
# Num timesteps: 258000
# Best mean reward: -354.19 - Last mean reward per episode: -390.49
# Num timesteps: 259000
# Best mean reward: -354.19 - Last mean reward per episode: -392.81
# Num timesteps: 260000
# Best mean reward: -354.19 - Last mean reward per episode: -376.77
# Num timesteps: 261000
# Best mean reward: -354.19 - Last mean reward per episode: -390.01
# Num timesteps: 262000
# Best mean reward: -354.19 - Last mean reward per episode: -392.54
# Num timesteps: 263000
# Best mean reward: -354.19 - Last mean reward per episode: -395.97
# Num timesteps: 264000
# Best mean reward: -354.19 - Last mean reward per episode: -410.45
# Num timesteps: 265000
# Best mean reward: -354.19 - Last mean reward per episode: -401.47
# Num timesteps: 266000
# Best mean reward: -354.19 - Last mean reward per episode: -404.87
# Num timesteps: 267000
# Best mean reward: -354.19 - Last mean reward per episode: -407.64
# Num timesteps: 268000
# Best mean reward: -354.19 - Last mean reward per episode: -389.42
# Num timesteps: 269000
# Best mean reward: -354.19 - Last mean reward per episode: -389.10
# Num timesteps: 270000
# Best mean reward: -354.19 - Last mean reward per episode: -392.24
# Num timesteps: 271000
# Best mean reward: -354.19 - Last mean reward per episode: -380.03
# Num timesteps: 272000
# Best mean reward: -354.19 - Last mean reward per episode: -373.41
# Num timesteps: 273000
# Best mean reward: -354.19 - Last mean reward per episode: -381.55
# Num timesteps: 274000
# Best mean reward: -354.19 - Last mean reward per episode: -364.83
# Num timesteps: 275000
# Best mean reward: -354.19 - Last mean reward per episode: -357.50
# Num timesteps: 276000
# Best mean reward: -354.19 - Last mean reward per episode: -370.32
# Num timesteps: 277000
# Best mean reward: -354.19 - Last mean reward per episode: -378.28
# Num timesteps: 278000
# Best mean reward: -354.19 - Last mean reward per episode: -377.48
# Num timesteps: 279000
# Best mean reward: -354.19 - Last mean reward per episode: -380.40
# Num timesteps: 280000
# Best mean reward: -354.19 - Last mean reward per episode: -379.07
# Num timesteps: 281000
# Best mean reward: -354.19 - Last mean reward per episode: -369.92
# Num timesteps: 282000
# Best mean reward: -354.19 - Last mean reward per episode: -380.85
# Num timesteps: 283000
# Best mean reward: -354.19 - Last mean reward per episode: -375.87
# Num timesteps: 284000
# Best mean reward: -354.19 - Last mean reward per episode: -362.86
# Num timesteps: 285000
# Best mean reward: -354.19 - Last mean reward per episode: -355.00
# Num timesteps: 286000
# Best mean reward: -354.19 - Last mean reward per episode: -348.49
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 287000
# Best mean reward: -348.49 - Last mean reward per episode: -334.72
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 288000
# Best mean reward: -334.72 - Last mean reward per episode: -347.97
# Num timesteps: 289000
# Best mean reward: -334.72 - Last mean reward per episode: -352.04
# Num timesteps: 290000
# Best mean reward: -334.72 - Last mean reward per episode: -331.08
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 291000
# Best mean reward: -331.08 - Last mean reward per episode: -348.40
# Num timesteps: 292000
# Best mean reward: -331.08 - Last mean reward per episode: -360.61
# Num timesteps: 293000
# Best mean reward: -331.08 - Last mean reward per episode: -348.67
# Num timesteps: 294000
# Best mean reward: -331.08 - Last mean reward per episode: -349.57
# Num timesteps: 295000
# Best mean reward: -331.08 - Last mean reward per episode: -351.48
# Num timesteps: 296000
# Best mean reward: -331.08 - Last mean reward per episode: -340.53
# Num timesteps: 297000
# Best mean reward: -331.08 - Last mean reward per episode: -323.53
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 298000
# Best mean reward: -323.53 - Last mean reward per episode: -304.51
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 299000
# Best mean reward: -304.51 - Last mean reward per episode: -293.50
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 300000
# Best mean reward: -293.50 - Last mean reward per episode: -301.03
# Num timesteps: 301000
# Best mean reward: -293.50 - Last mean reward per episode: -298.09
# Num timesteps: 302000
# Best mean reward: -293.50 - Last mean reward per episode: -283.75
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 303000
# Best mean reward: -283.75 - Last mean reward per episode: -277.83
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 304000
# Best mean reward: -277.83 - Last mean reward per episode: -287.67
# Num timesteps: 305000
# Best mean reward: -277.83 - Last mean reward per episode: -283.65
# Num timesteps: 306000
# Best mean reward: -277.83 - Last mean reward per episode: -286.27
# Num timesteps: 307000
# Best mean reward: -277.83 - Last mean reward per episode: -292.32
# Num timesteps: 308000
# Best mean reward: -277.83 - Last mean reward per episode: -278.97
# Num timesteps: 309000
# Best mean reward: -277.83 - Last mean reward per episode: -277.64
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 310000
# Best mean reward: -277.64 - Last mean reward per episode: -283.16
# Num timesteps: 311000
# Best mean reward: -277.64 - Last mean reward per episode: -272.93
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 312000
# Best mean reward: -272.93 - Last mean reward per episode: -257.23
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 313000
# Best mean reward: -257.23 - Last mean reward per episode: -254.09
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 314000
# Best mean reward: -254.09 - Last mean reward per episode: -251.73
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 315000
# Best mean reward: -251.73 - Last mean reward per episode: -243.52
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 316000
# Best mean reward: -243.52 - Last mean reward per episode: -236.86
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 317000
# Best mean reward: -236.86 - Last mean reward per episode: -240.90
# Num timesteps: 318000
# Best mean reward: -236.86 - Last mean reward per episode: -250.34
# Num timesteps: 319000
# Best mean reward: -236.86 - Last mean reward per episode: -261.10
# Num timesteps: 320000
# Best mean reward: -236.86 - Last mean reward per episode: -273.84
# Num timesteps: 321000
# Best mean reward: -236.86 - Last mean reward per episode: -272.59
# Num timesteps: 322000
# Best mean reward: -236.86 - Last mean reward per episode: -276.66
# Num timesteps: 323000
# Best mean reward: -236.86 - Last mean reward per episode: -276.75
# Num timesteps: 324000
# Best mean reward: -236.86 - Last mean reward per episode: -273.23
# Num timesteps: 325000
# Best mean reward: -236.86 - Last mean reward per episode: -288.77
# Num timesteps: 326000
# Best mean reward: -236.86 - Last mean reward per episode: -285.91
# Num timesteps: 327000
# Best mean reward: -236.86 - Last mean reward per episode: -279.84
# Num timesteps: 328000
# Best mean reward: -236.86 - Last mean reward per episode: -290.76
# Num timesteps: 329000
# Best mean reward: -236.86 - Last mean reward per episode: -285.32
# Num timesteps: 330000
# Best mean reward: -236.86 - Last mean reward per episode: -281.34
# Num timesteps: 331000
# Best mean reward: -236.86 - Last mean reward per episode: -277.20
# Num timesteps: 332000
# Best mean reward: -236.86 - Last mean reward per episode: -287.88
# Num timesteps: 333000
# Best mean reward: -236.86 - Last mean reward per episode: -289.16
# Num timesteps: 334000
# Best mean reward: -236.86 - Last mean reward per episode: -287.99
# Num timesteps: 335000
# Best mean reward: -236.86 - Last mean reward per episode: -298.86
# Num timesteps: 336000
# Best mean reward: -236.86 - Last mean reward per episode: -302.84
# Num timesteps: 337000
# Best mean reward: -236.86 - Last mean reward per episode: -298.57
# Num timesteps: 338000
# Best mean reward: -236.86 - Last mean reward per episode: -299.17
# Num timesteps: 339000
# Best mean reward: -236.86 - Last mean reward per episode: -298.52
# Num timesteps: 340000
# Best mean reward: -236.86 - Last mean reward per episode: -287.41
# Num timesteps: 341000
# Best mean reward: -236.86 - Last mean reward per episode: -289.94
# Num timesteps: 342000
# Best mean reward: -236.86 - Last mean reward per episode: -287.66
# Num timesteps: 343000
# Best mean reward: -236.86 - Last mean reward per episode: -291.14
# Num timesteps: 344000
# Best mean reward: -236.86 - Last mean reward per episode: -278.20
# Num timesteps: 345000
# Best mean reward: -236.86 - Last mean reward per episode: -271.85
# Num timesteps: 346000
# Best mean reward: -236.86 - Last mean reward per episode: -269.30
# Num timesteps: 347000
# Best mean reward: -236.86 - Last mean reward per episode: -270.53
# Num timesteps: 348000
# Best mean reward: -236.86 - Last mean reward per episode: -254.33
# Num timesteps: 349000
# Best mean reward: -236.86 - Last mean reward per episode: -258.65
# Num timesteps: 350000
# Best mean reward: -236.86 - Last mean reward per episode: -262.16
# Num timesteps: 351000
# Best mean reward: -236.86 - Last mean reward per episode: -261.60
# Num timesteps: 352000
# Best mean reward: -236.86 - Last mean reward per episode: -252.08
# Num timesteps: 353000
# Best mean reward: -236.86 - Last mean reward per episode: -247.33
# Num timesteps: 354000
# Best mean reward: -236.86 - Last mean reward per episode: -245.04
# Num timesteps: 355000
# Best mean reward: -236.86 - Last mean reward per episode: -245.73
# Num timesteps: 356000
# Best mean reward: -236.86 - Last mean reward per episode: -244.92
# Num timesteps: 357000
# Best mean reward: -236.86 - Last mean reward per episode: -243.19
# Num timesteps: 358000
# Best mean reward: -236.86 - Last mean reward per episode: -235.50
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 359000
# Best mean reward: -235.50 - Last mean reward per episode: -225.29
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 360000
# Best mean reward: -225.29 - Last mean reward per episode: -217.42
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 361000
# Best mean reward: -217.42 - Last mean reward per episode: -208.18
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 362000
# Best mean reward: -208.18 - Last mean reward per episode: -215.03
# Num timesteps: 363000
# Best mean reward: -208.18 - Last mean reward per episode: -212.53
# Num timesteps: 364000
# Best mean reward: -208.18 - Last mean reward per episode: -217.76
# Num timesteps: 365000
# Best mean reward: -208.18 - Last mean reward per episode: -211.42
# Num timesteps: 366000
# Best mean reward: -208.18 - Last mean reward per episode: -213.00
# Num timesteps: 367000
# Best mean reward: -208.18 - Last mean reward per episode: -214.02
# Num timesteps: 368000
# Best mean reward: -208.18 - Last mean reward per episode: -216.60
# Num timesteps: 369000
# Best mean reward: -208.18 - Last mean reward per episode: -210.42
# Num timesteps: 370000
# Best mean reward: -208.18 - Last mean reward per episode: -203.97
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 371000
# Best mean reward: -203.97 - Last mean reward per episode: -204.16
# Num timesteps: 372000
# Best mean reward: -203.97 - Last mean reward per episode: -202.78
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 373000
# Best mean reward: -202.78 - Last mean reward per episode: -202.81
# Num timesteps: 374000
# Best mean reward: -202.78 - Last mean reward per episode: -206.95
# Num timesteps: 375000
# Best mean reward: -202.78 - Last mean reward per episode: -202.73
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 376000
# Best mean reward: -202.73 - Last mean reward per episode: -199.54
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 377000
# Best mean reward: -199.54 - Last mean reward per episode: -199.52
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 378000
# Best mean reward: -199.52 - Last mean reward per episode: -199.99
# Num timesteps: 379000
# Best mean reward: -199.52 - Last mean reward per episode: -197.79
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 380000
# Best mean reward: -197.79 - Last mean reward per episode: -201.37
# Num timesteps: 381000
# Best mean reward: -197.79 - Last mean reward per episode: -205.78
# Num timesteps: 382000
# Best mean reward: -197.79 - Last mean reward per episode: -194.22
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 383000
# Best mean reward: -194.22 - Last mean reward per episode: -189.86
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 384000
# Best mean reward: -189.86 - Last mean reward per episode: -189.47
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 385000
# Best mean reward: -189.47 - Last mean reward per episode: -184.07
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 386000
# Best mean reward: -184.07 - Last mean reward per episode: -182.43
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 387000
# Best mean reward: -182.43 - Last mean reward per episode: -182.57
# Num timesteps: 388000
# Best mean reward: -182.43 - Last mean reward per episode: -183.76
# Num timesteps: 389000
# Best mean reward: -182.43 - Last mean reward per episode: -183.20
# Num timesteps: 390000
# Best mean reward: -182.43 - Last mean reward per episode: -179.86
# Saving new best model to /tmp/gym/best_model.zip
# Num timesteps: 391000
# Best mean reward: -179.86 - Last mean reward per episode: -191.10
# Num timesteps: 392000
# Best mean reward: -179.86 - Last mean reward per episode: -182.26
# Num timesteps: 393000
# Best mean reward: -179.86 - Last mean reward per episode: -188.08
# Num timesteps: 394000
# Best mean reward: -179.86 - Last mean reward per episode: -198.55
# Num timesteps: 395000
# Best mean reward: -179.86 - Last mean reward per episode: -200.79
# Num timesteps: 396000
# Best mean reward: -179.86 - Last mean reward per episode: -202.23
# Num timesteps: 397000
# Best mean reward: -179.86 - Last mean reward per episode: -199.82
# Num timesteps: 398000
# Best mean reward: -179.86 - Last mean reward per episode: -203.48
# Num timesteps: 399000
# Best mean reward: -179.86 - Last mean reward per episode: -219.36
# Num timesteps: 400000
# Best mean reward: -179.86 - Last mean reward per episode: -219.58
# Num timesteps: 401000
# Best mean reward: -179.86 - Last mean reward per episode: -223.63
# Num timesteps: 402000
# Best mean reward: -179.86 - Last mean reward per episode: -229.74
# Num timesteps: 403000
# Best mean reward: -179.86 - Last mean reward per episode: -234.09
# Num timesteps: 404000
# Best mean reward: -179.86 - Last mean reward per episode: -236.96
# Num timesteps: 405000
# Best mean reward: -179.86 - Last mean reward per episode: -241.85
# Num timesteps: 406000
# Best mean reward: -179.86 - Last mean reward per episode: -244.46
# Num timesteps: 407000
# Best mean reward: -179.86 - Last mean reward per episode: -243.20
# Num timesteps: 408000
# Best mean reward: -179.86 - Last mean reward per episode: -242.07
# Num timesteps: 409000
# Best mean reward: -179.86 - Last mean reward per episode: -244.95
# Num timesteps: 410000
# Best mean reward: -179.86 - Last mean reward per episode: -245.05
# Num timesteps: 411000
# Best mean reward: -179.86 - Last mean reward per episode: -231.17
# Num timesteps: 412000
# Best mean reward: -179.86 - Last mean reward per episode: -237.93
# Num timesteps: 413000
# Best mean reward: -179.86 - Last mean reward per episode: -238.51
# Num timesteps: 414000
# Best mean reward: -179.86 - Last mean reward per episode: -234.18
# Num timesteps: 415000
# Best mean reward: -179.86 - Last mean reward per episode: -241.66
# Num timesteps: 416000
# Best mean reward: -179.86 - Last mean reward per episode: -249.42
# Num timesteps: 417000
# Best mean reward: -179.86 - Last mean reward per episode: -253.62
# Num timesteps: 418000
# Best mean reward: -179.86 - Last mean reward per episode: -249.76
# Num timesteps: 419000
# Best mean reward: -179.86 - Last mean reward per episode: -235.31
# Num timesteps: 420000
# Best mean reward: -179.86 - Last mean reward per episode: -241.08
# Num timesteps: 421000
# Best mean reward: -179.86 - Last mean reward per episode: -235.39
# Num timesteps: 422000
# Best mean reward: -179.86 - Last mean reward per episode: -232.91
# Num timesteps: 423000
# Best mean reward: -179.86 - Last mean reward per episode: -243.79
# Num timesteps: 424000
# Best mean reward: -179.86 - Last mean reward per episode: -237.22
# Num timesteps: 425000
# Best mean reward: -179.86 - Last mean reward per episode: -252.33
# Num timesteps: 426000
# Best mean reward: -179.86 - Last mean reward per episode: -249.71
# Num timesteps: 427000
# Best mean reward: -179.86 - Last mean reward per episode: -257.74
# Num timesteps: 428000
# Best mean reward: -179.86 - Last mean reward per episode: -262.25
# Num timesteps: 429000
# Best mean reward: -179.86 - Last mean reward per episode: -268.87
# Num timesteps: 430000
# Best mean reward: -179.86 - Last mean reward per episode: -276.11
# Num timesteps: 431000
# Best mean reward: -179.86 - Last mean reward per episode: -277.32
# Num timesteps: 432000
# Best mean reward: -179.86 - Last mean reward per episode: -277.24
# Num timesteps: 433000
# Best mean reward: -179.86 - Last mean reward per episode: -268.25
# Num timesteps: 434000
# Best mean reward: -179.86 - Last mean reward per episode: -262.98
# Num timesteps: 435000
# Best mean reward: -179.86 - Last mean reward per episode: -254.46
# Num timesteps: 436000
# Best mean reward: -179.86 - Last mean reward per episode: -246.67
# Num timesteps: 437000
# Best mean reward: -179.86 - Last mean reward per episode: -242.32
# Num timesteps: 438000
# Best mean reward: -179.86 - Last mean reward per episode: -240.84
# Num timesteps: 439000
# Best mean reward: -179.86 - Last mean reward per episode: -241.69
# Num timesteps: 440000
# Best mean reward: -179.86 - Last mean reward per episode: -231.99
# Num timesteps: 441000
# Best mean reward: -179.86 - Last mean reward per episode: -238.39
# Num timesteps: 442000
# Best mean reward: -179.86 - Last mean reward per episode: -237.94
# Num timesteps: 443000
# Best mean reward: -179.86 - Last mean reward per episode: -229.44
# Num timesteps: 444000
# Best mean reward: -179.86 - Last mean reward per episode: -230.71
# Num timesteps: 445000
# Best mean reward: -179.86 - Last mean reward per episode: -213.12
# Num timesteps: 446000
# Best mean reward: -179.86 - Last mean reward per episode: -211.97
# Num timesteps: 447000
# Best mean reward: -179.86 - Last mean reward per episode: -209.74
# Num timesteps: 448000
# Best mean reward: -179.86 - Last mean reward per episode: -204.25
# Num timesteps: 449000
# Best mean reward: -179.86 - Last mean reward per episode: -196.02
# Num timesteps: 450000
# Best mean reward: -179.86 - Last mean reward per episode: -191.30
# Num timesteps: 451000
# Best mean reward: -179.86 - Last mean reward per episode: -194.96
# Num timesteps: 452000
# Best mean reward: -179.86 - Last mean reward per episode: -191.97
# Num timesteps: 453000
# Best mean reward: -179.86 - Last mean reward per episode: -191.31
# Num timesteps: 454000
# Best mean reward: -179.86 - Last mean reward per episode: -190.99
# Num timesteps: 455000
# Best mean reward: -179.86 - Last mean reward per episode: -188.50
# Num timesteps: 456000
# Best mean reward: -179.86 - Last mean reward per episode: -190.59
# Num timesteps: 457000
# Best mean reward: -179.86 - Last mean reward per episode: -189.40
# Num timesteps: 458000
# Best mean reward: -179.86 - Last mean reward per episode: -195.01
# Num timesteps: 459000
# Best mean reward: -179.86 - Last mean reward per episode: -198.61
# Num timesteps: 460000
# Best mean reward: -179.86 - Last mean reward per episode: -207.14
# Num timesteps: 461000
# Best mean reward: -179.86 - Last mean reward per episode: -221.60
# Num timesteps: 462000
# Best mean reward: -179.86 - Last mean reward per episode: -223.27
# Num timesteps: 463000
# Best mean reward: -179.86 - Last mean reward per episode: -219.93
# Num timesteps: 464000
# Best mean reward: -179.86 - Last mean reward per episode: -224.66
# Num timesteps: 465000
# Best mean reward: -179.86 - Last mean reward per episode: -228.44
# Num timesteps: 466000
# Best mean reward: -179.86 - Last mean reward per episode: -236.31
# Num timesteps: 467000
# Best mean reward: -179.86 - Last mean reward per episode: -230.41
# Num timesteps: 468000
# Best mean reward: -179.86 - Last mean reward per episode: -234.90
# Num timesteps: 469000
# Best mean reward: -179.86 - Last mean reward per episode: -229.78
# Num timesteps: 470000
# Best mean reward: -179.86 - Last mean reward per episode: -228.80
# Num timesteps: 471000
# Best mean reward: -179.86 - Last mean reward per episode: -226.52
# Num timesteps: 472000
# Best mean reward: -179.86 - Last mean reward per episode: -233.40
# Num timesteps: 473000
# Best mean reward: -179.86 - Last mean reward per episode: -242.69
# Num timesteps: 474000
# Best mean reward: -179.86 - Last mean reward per episode: -242.63
# Num timesteps: 475000
# Best mean reward: -179.86 - Last mean reward per episode: -238.87
# Num timesteps: 476000
# Best mean reward: -179.86 - Last mean reward per episode: -239.29
# Num timesteps: 477000
# Best mean reward: -179.86 - Last mean reward per episode: -245.86
# Num timesteps: 478000
# Best mean reward: -179.86 - Last mean reward per episode: -245.18
# Num timesteps: 479000
# Best mean reward: -179.86 - Last mean reward per episode: -234.18
# Num timesteps: 480000
# Best mean reward: -179.86 - Last mean reward per episode: -225.51
# Num timesteps: 481000
# Best mean reward: -179.86 - Last mean reward per episode: -204.40
# Num timesteps: 482000
# Best mean reward: -179.86 - Last mean reward per episode: -201.85
# Num timesteps: 483000
# Best mean reward: -179.86 - Last mean reward per episode: -195.29
# Num timesteps: 484000
# Best mean reward: -179.86 - Last mean reward per episode: -199.14
# Num timesteps: 485000
# Best mean reward: -179.86 - Last mean reward per episode: -196.07
# Num timesteps: 486000
# Best mean reward: -179.86 - Last mean reward per episode: -190.52
# Num timesteps: 487000
# Best mean reward: -179.86 - Last mean reward per episode: -197.35
# Num timesteps: 488000
# Best mean reward: -179.86 - Last mean reward per episode: -196.10
# Num timesteps: 489000
# Best mean reward: -179.86 - Last mean reward per episode: -203.33
# Num timesteps: 490000
# Best mean reward: -179.86 - Last mean reward per episode: -202.62
# Num timesteps: 491000
# Best mean reward: -179.86 - Last mean reward per episode: -215.38
# Num timesteps: 492000
# Best mean reward: -179.86 - Last mean reward per episode: -204.75
# Num timesteps: 493000
# Best mean reward: -179.86 - Last mean reward per episode: -197.49
# Num timesteps: 494000
# Best mean reward: -179.86 - Last mean reward per episode: -209.01
# Num timesteps: 495000
# Best mean reward: -179.86 - Last mean reward per episode: -224.95
# Num timesteps: 496000
# Best mean reward: -179.86 - Last mean reward per episode: -229.10
# Num timesteps: 497000
# Best mean reward: -179.86 - Last mean reward per episode: -221.23
# Num timesteps: 498000
# Best mean reward: -179.86 - Last mean reward per episode: -216.45
# Num timesteps: 499000
# Best mean reward: -179.86 - Last mean reward per episode: -218.83
# Num timesteps: 500000
# Best mean reward: -179.86 - Last mean reward per episode: -228.01
# Num timesteps: 501000
# Best mean reward: -179.86 - Last mean reward per episode: -229.16

# %%
# Plotting

def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, 'valid')


def plot_results(log_folder, title='Learning Curve'):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    
    x, y = ts2xy(load_results(log_folder), 'timesteps')

    y_mean = moving_average(y, window=50)
    # Truncate x
    x_mean = x[len(x) - len(y_mean):]

    fig = plt.figure(title)
    plt.plot(x, y, alpha=0.4, label="Rewards")
    plt.plot(x_mean, y_mean, label="Mean rewards - wd:50")
    plt.xlabel('Number of Timesteps')
    plt.ylabel('Rewards')
    plt.title(title)
    plt.legend(loc="best")
    plt.show()


plot_results(log_dir)

# %%
# Test 

scores = []
for i in range(100):
    obs = env.reset()
    score = 0
    done = False
    
    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        score += reward
    
    scores.append(score)

np.mean(scores)
# Out:
# -344.4536651262192
