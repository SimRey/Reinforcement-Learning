# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import PPO
from stable_baselines3.common import results_plotter
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model')
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

          # Retrieve training reward
          x, y = ts2xy(load_results(self.log_dir), 'timesteps')
          if len(x) > 0:
              # Mean training reward over the last 100 episodes
              mean_reward = np.mean(y[-100:])
              if self.verbose > 0:
                print(f"Num timesteps: {self.num_timesteps}")
                print(f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}")

              # New best model, you could save the agent here
              if mean_reward > self.best_mean_reward:
                  self.best_mean_reward = mean_reward
                  # Example for saving best model
                  if self.verbose > 0:
                    print(f"Saving new best model to {self.save_path}.zip")
                  self.model.save(self.save_path)

        return True

# %%
# Create and wrap the environment

# Create log dir
log_dir = "C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = gym.make("Pendulum-v1")

# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)

# %%
# Create and train the agent

# Create the callback: check every 1000 steps
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir)
# Create RL model
model = PPO("MlpPolicy", env)
# Train the agent
model.learn(total_timesteps=int(500e3), callback=callback)
# Out:
# Num timesteps: 1000
# Best mean reward: -inf - Last mean reward per episode: -1348.63
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 2000
# Best mean reward: -1348.63 - Last mean reward per episode: -1336.18
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 3000
# Best mean reward: -1336.18 - Last mean reward per episode: -1213.51
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 4000
# Best mean reward: -1213.51 - Last mean reward per episode: -1220.26
# Num timesteps: 5000
# Best mean reward: -1213.51 - Last mean reward per episode: -1223.24
# Num timesteps: 6000
# Best mean reward: -1213.51 - Last mean reward per episode: -1260.90
# Num timesteps: 7000
# Best mean reward: -1213.51 - Last mean reward per episode: -1257.36
# Num timesteps: 8000
# Best mean reward: -1213.51 - Last mean reward per episode: -1233.88
# Num timesteps: 9000
# Best mean reward: -1213.51 - Last mean reward per episode: -1236.49
# Num timesteps: 10000
# Best mean reward: -1213.51 - Last mean reward per episode: -1254.62
# Num timesteps: 11000
# Best mean reward: -1213.51 - Last mean reward per episode: -1271.13
# Num timesteps: 12000
# Best mean reward: -1213.51 - Last mean reward per episode: -1258.18
# Num timesteps: 13000
# Best mean reward: -1213.51 - Last mean reward per episode: -1263.62
# Num timesteps: 14000
# Best mean reward: -1213.51 - Last mean reward per episode: -1261.02
# Num timesteps: 15000
# Best mean reward: -1213.51 - Last mean reward per episode: -1262.58
# Num timesteps: 16000
# Best mean reward: -1213.51 - Last mean reward per episode: -1248.39
# Num timesteps: 17000
# Best mean reward: -1213.51 - Last mean reward per episode: -1241.54
# Num timesteps: 18000
# Best mean reward: -1213.51 - Last mean reward per episode: -1249.79
# Num timesteps: 19000
# Best mean reward: -1213.51 - Last mean reward per episode: -1257.22
# Num timesteps: 20000
# Best mean reward: -1213.51 - Last mean reward per episode: -1252.91
# Num timesteps: 21000
# Best mean reward: -1213.51 - Last mean reward per episode: -1250.73
# Num timesteps: 22000
# Best mean reward: -1213.51 - Last mean reward per episode: -1244.69
# Num timesteps: 23000
# Best mean reward: -1213.51 - Last mean reward per episode: -1258.51
# Num timesteps: 24000
# Best mean reward: -1213.51 - Last mean reward per episode: -1252.74
# Num timesteps: 25000
# Best mean reward: -1213.51 - Last mean reward per episode: -1251.21
# Num timesteps: 26000
# Best mean reward: -1213.51 - Last mean reward per episode: -1235.21
# Num timesteps: 27000
# Best mean reward: -1213.51 - Last mean reward per episode: -1222.04
# Num timesteps: 28000
# Best mean reward: -1213.51 - Last mean reward per episode: -1237.03
# Num timesteps: 29000
# Best mean reward: -1213.51 - Last mean reward per episode: -1236.55
# Num timesteps: 30000
# Best mean reward: -1213.51 - Last mean reward per episode: -1224.59
# Num timesteps: 31000
# Best mean reward: -1213.51 - Last mean reward per episode: -1215.94
# Num timesteps: 32000
# Best mean reward: -1213.51 - Last mean reward per episode: -1217.43
# Num timesteps: 33000
# Best mean reward: -1213.51 - Last mean reward per episode: -1213.99
# Num timesteps: 34000
# Best mean reward: -1213.51 - Last mean reward per episode: -1215.38
# Num timesteps: 35000
# Best mean reward: -1213.51 - Last mean reward per episode: -1200.37
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 36000
# Best mean reward: -1200.37 - Last mean reward per episode: -1208.37
# Num timesteps: 37000
# Best mean reward: -1200.37 - Last mean reward per episode: -1199.03
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 38000
# Best mean reward: -1199.03 - Last mean reward per episode: -1179.18
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 39000
# Best mean reward: -1179.18 - Last mean reward per episode: -1162.59
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 40000
# Best mean reward: -1162.59 - Last mean reward per episode: -1155.79
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 41000
# Best mean reward: -1155.79 - Last mean reward per episode: -1142.22
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 42000
# Best mean reward: -1142.22 - Last mean reward per episode: -1141.05
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 43000
# Best mean reward: -1141.05 - Last mean reward per episode: -1137.77
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 44000
# Best mean reward: -1137.77 - Last mean reward per episode: -1130.35
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 45000
# Best mean reward: -1130.35 - Last mean reward per episode: -1123.82
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 46000
# Best mean reward: -1123.82 - Last mean reward per episode: -1124.51
# Num timesteps: 47000
# Best mean reward: -1123.82 - Last mean reward per episode: -1127.63
# Num timesteps: 48000
# Best mean reward: -1123.82 - Last mean reward per episode: -1106.12
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 49000
# Best mean reward: -1106.12 - Last mean reward per episode: -1096.94
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 50000
# Best mean reward: -1096.94 - Last mean reward per episode: -1098.12
# Num timesteps: 51000
# Best mean reward: -1096.94 - Last mean reward per episode: -1087.74
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 52000
# Best mean reward: -1087.74 - Last mean reward per episode: -1081.92
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 53000
# Best mean reward: -1081.92 - Last mean reward per episode: -1071.93
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 54000
# Best mean reward: -1071.93 - Last mean reward per episode: -1068.85
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 55000
# Best mean reward: -1068.85 - Last mean reward per episode: -1076.39
# Num timesteps: 56000
# Best mean reward: -1068.85 - Last mean reward per episode: -1063.59
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 57000
# Best mean reward: -1063.59 - Last mean reward per episode: -1076.24
# Num timesteps: 58000
# Best mean reward: -1063.59 - Last mean reward per episode: -1079.57
# Num timesteps: 59000
# Best mean reward: -1063.59 - Last mean reward per episode: -1077.43
# Num timesteps: 60000
# Best mean reward: -1063.59 - Last mean reward per episode: -1085.46
# Num timesteps: 61000
# Best mean reward: -1063.59 - Last mean reward per episode: -1086.02
# Num timesteps: 62000
# Best mean reward: -1063.59 - Last mean reward per episode: -1085.63
# Num timesteps: 63000
# Best mean reward: -1063.59 - Last mean reward per episode: -1076.17
# Num timesteps: 64000
# Best mean reward: -1063.59 - Last mean reward per episode: -1084.36
# Num timesteps: 65000
# Best mean reward: -1063.59 - Last mean reward per episode: -1085.44
# Num timesteps: 66000
# Best mean reward: -1063.59 - Last mean reward per episode: -1089.24
# Num timesteps: 67000
# Best mean reward: -1063.59 - Last mean reward per episode: -1087.08
# Num timesteps: 68000
# Best mean reward: -1063.59 - Last mean reward per episode: -1090.37
# Num timesteps: 69000
# Best mean reward: -1063.59 - Last mean reward per episode: -1086.01
# Num timesteps: 70000
# Best mean reward: -1063.59 - Last mean reward per episode: -1071.40
# Num timesteps: 71000
# Best mean reward: -1063.59 - Last mean reward per episode: -1075.23
# Num timesteps: 72000
# Best mean reward: -1063.59 - Last mean reward per episode: -1072.56
# Num timesteps: 73000
# Best mean reward: -1063.59 - Last mean reward per episode: -1078.09
# Num timesteps: 74000
# Best mean reward: -1063.59 - Last mean reward per episode: -1077.69
# Num timesteps: 75000
# Best mean reward: -1063.59 - Last mean reward per episode: -1074.79
# Num timesteps: 76000
# Best mean reward: -1063.59 - Last mean reward per episode: -1079.20
# Num timesteps: 77000
# Best mean reward: -1063.59 - Last mean reward per episode: -1071.55
# Num timesteps: 78000
# Best mean reward: -1063.59 - Last mean reward per episode: -1070.68
# Num timesteps: 79000
# Best mean reward: -1063.59 - Last mean reward per episode: -1069.66
# Num timesteps: 80000
# Best mean reward: -1063.59 - Last mean reward per episode: -1062.20
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 81000
# Best mean reward: -1062.20 - Last mean reward per episode: -1063.24
# Num timesteps: 82000
# Best mean reward: -1062.20 - Last mean reward per episode: -1054.78
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 83000
# Best mean reward: -1054.78 - Last mean reward per episode: -1059.34
# Num timesteps: 84000
# Best mean reward: -1054.78 - Last mean reward per episode: -1057.46
# Num timesteps: 85000
# Best mean reward: -1054.78 - Last mean reward per episode: -1050.06
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 86000
# Best mean reward: -1050.06 - Last mean reward per episode: -1037.97
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 87000
# Best mean reward: -1037.97 - Last mean reward per episode: -1037.98
# Num timesteps: 88000
# Best mean reward: -1037.97 - Last mean reward per episode: -1037.53
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 89000
# Best mean reward: -1037.53 - Last mean reward per episode: -1042.02
# Num timesteps: 90000
# Best mean reward: -1037.53 - Last mean reward per episode: -1048.81
# Num timesteps: 91000
# Best mean reward: -1037.53 - Last mean reward per episode: -1044.45
# Num timesteps: 92000
# Best mean reward: -1037.53 - Last mean reward per episode: -1049.25
# Num timesteps: 93000
# Best mean reward: -1037.53 - Last mean reward per episode: -1042.97
# Num timesteps: 94000
# Best mean reward: -1037.53 - Last mean reward per episode: -1035.65
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 95000
# Best mean reward: -1035.65 - Last mean reward per episode: -1030.32
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 96000
# Best mean reward: -1030.32 - Last mean reward per episode: -1024.89
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 97000
# Best mean reward: -1024.89 - Last mean reward per episode: -1020.42
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 98000
# Best mean reward: -1020.42 - Last mean reward per episode: -1013.42
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 99000
# Best mean reward: -1013.42 - Last mean reward per episode: -1006.98
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 100000
# Best mean reward: -1006.98 - Last mean reward per episode: -1008.43
# Num timesteps: 101000
# Best mean reward: -1006.98 - Last mean reward per episode: -1011.24
# Num timesteps: 102000
# Best mean reward: -1006.98 - Last mean reward per episode: -1009.80
# Num timesteps: 103000
# Best mean reward: -1006.98 - Last mean reward per episode: -1016.85
# Num timesteps: 104000
# Best mean reward: -1006.98 - Last mean reward per episode: -1010.23
# Num timesteps: 105000
# Best mean reward: -1006.98 - Last mean reward per episode: -1015.43
# Num timesteps: 106000
# Best mean reward: -1006.98 - Last mean reward per episode: -1014.40
# Num timesteps: 107000
# Best mean reward: -1006.98 - Last mean reward per episode: -1020.20
# Num timesteps: 108000
# Best mean reward: -1006.98 - Last mean reward per episode: -1028.80
# Num timesteps: 109000
# Best mean reward: -1006.98 - Last mean reward per episode: -1029.18
# Num timesteps: 110000
# Best mean reward: -1006.98 - Last mean reward per episode: -1031.97
# Num timesteps: 111000
# Best mean reward: -1006.98 - Last mean reward per episode: -1031.76
# Num timesteps: 112000
# Best mean reward: -1006.98 - Last mean reward per episode: -1023.52
# Num timesteps: 113000
# Best mean reward: -1006.98 - Last mean reward per episode: -1021.14
# Num timesteps: 114000
# Best mean reward: -1006.98 - Last mean reward per episode: -1018.04
# Num timesteps: 115000
# Best mean reward: -1006.98 - Last mean reward per episode: -1016.89
# Num timesteps: 116000
# Best mean reward: -1006.98 - Last mean reward per episode: -1025.93
# Num timesteps: 117000
# Best mean reward: -1006.98 - Last mean reward per episode: -1029.88
# Num timesteps: 118000
# Best mean reward: -1006.98 - Last mean reward per episode: -1032.54
# Num timesteps: 119000
# Best mean reward: -1006.98 - Last mean reward per episode: -1040.43
# Num timesteps: 120000
# Best mean reward: -1006.98 - Last mean reward per episode: -1037.49
# Num timesteps: 121000
# Best mean reward: -1006.98 - Last mean reward per episode: -1031.18
# Num timesteps: 122000
# Best mean reward: -1006.98 - Last mean reward per episode: -1036.70
# Num timesteps: 123000
# Best mean reward: -1006.98 - Last mean reward per episode: -1026.56
# Num timesteps: 124000
# Best mean reward: -1006.98 - Last mean reward per episode: -1029.77
# Num timesteps: 125000
# Best mean reward: -1006.98 - Last mean reward per episode: -1021.77
# Num timesteps: 126000
# Best mean reward: -1006.98 - Last mean reward per episode: -1018.66
# Num timesteps: 127000
# Best mean reward: -1006.98 - Last mean reward per episode: -1016.81
# Num timesteps: 128000
# Best mean reward: -1006.98 - Last mean reward per episode: -1008.70
# Num timesteps: 129000
# Best mean reward: -1006.98 - Last mean reward per episode: -1003.36
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 130000
# Best mean reward: -1003.36 - Last mean reward per episode: -1003.06
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 131000
# Best mean reward: -1003.06 - Last mean reward per episode: -1001.19
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 132000
# Best mean reward: -1001.19 - Last mean reward per episode: -1011.95
# Num timesteps: 133000
# Best mean reward: -1001.19 - Last mean reward per episode: -1006.71
# Num timesteps: 134000
# Best mean reward: -1001.19 - Last mean reward per episode: -1011.60
# Num timesteps: 135000
# Best mean reward: -1001.19 - Last mean reward per episode: -1013.51
# Num timesteps: 136000
# Best mean reward: -1001.19 - Last mean reward per episode: -1009.11
# Num timesteps: 137000
# Best mean reward: -1001.19 - Last mean reward per episode: -1014.77
# Num timesteps: 138000
# Best mean reward: -1001.19 - Last mean reward per episode: -1019.21
# Num timesteps: 139000
# Best mean reward: -1001.19 - Last mean reward per episode: -1025.54
# Num timesteps: 140000
# Best mean reward: -1001.19 - Last mean reward per episode: -1022.37
# Num timesteps: 141000
# Best mean reward: -1001.19 - Last mean reward per episode: -1025.41
# Num timesteps: 142000
# Best mean reward: -1001.19 - Last mean reward per episode: -1023.76
# Num timesteps: 143000
# Best mean reward: -1001.19 - Last mean reward per episode: -1020.85
# Num timesteps: 144000
# Best mean reward: -1001.19 - Last mean reward per episode: -1024.07
# Num timesteps: 145000
# Best mean reward: -1001.19 - Last mean reward per episode: -1026.03
# Num timesteps: 146000
# Best mean reward: -1001.19 - Last mean reward per episode: -1028.64
# Num timesteps: 147000
# Best mean reward: -1001.19 - Last mean reward per episode: -1020.56
# Num timesteps: 148000
# Best mean reward: -1001.19 - Last mean reward per episode: -1016.94
# Num timesteps: 149000
# Best mean reward: -1001.19 - Last mean reward per episode: -1018.25
# Num timesteps: 150000
# Best mean reward: -1001.19 - Last mean reward per episode: -1009.47
# Num timesteps: 151000
# Best mean reward: -1001.19 - Last mean reward per episode: -1003.93
# Num timesteps: 152000
# Best mean reward: -1001.19 - Last mean reward per episode: -1004.00
# Num timesteps: 153000
# Best mean reward: -1001.19 - Last mean reward per episode: -1006.82
# Num timesteps: 154000
# Best mean reward: -1001.19 - Last mean reward per episode: -999.96
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 155000
# Best mean reward: -999.96 - Last mean reward per episode: -997.14
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 156000
# Best mean reward: -997.14 - Last mean reward per episode: -991.18
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 157000
# Best mean reward: -991.18 - Last mean reward per episode: -981.09
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 158000
# Best mean reward: -981.09 - Last mean reward per episode: -976.75
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 159000
# Best mean reward: -976.75 - Last mean reward per episode: -963.43
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 160000
# Best mean reward: -963.43 - Last mean reward per episode: -967.84
# Num timesteps: 161000
# Best mean reward: -963.43 - Last mean reward per episode: -967.79
# Num timesteps: 162000
# Best mean reward: -963.43 - Last mean reward per episode: -954.15
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 163000
# Best mean reward: -954.15 - Last mean reward per episode: -953.61
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 164000
# Best mean reward: -953.61 - Last mean reward per episode: -954.58
# Num timesteps: 165000
# Best mean reward: -953.61 - Last mean reward per episode: -945.51
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 166000
# Best mean reward: -945.51 - Last mean reward per episode: -940.88
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 167000
# Best mean reward: -940.88 - Last mean reward per episode: -929.04
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 168000
# Best mean reward: -929.04 - Last mean reward per episode: -929.69
# Num timesteps: 169000
# Best mean reward: -929.04 - Last mean reward per episode: -926.76
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 170000
# Best mean reward: -926.76 - Last mean reward per episode: -928.94
# Num timesteps: 171000
# Best mean reward: -926.76 - Last mean reward per episode: -933.65
# Num timesteps: 172000
# Best mean reward: -926.76 - Last mean reward per episode: -929.98
# Num timesteps: 173000
# Best mean reward: -926.76 - Last mean reward per episode: -935.90
# Num timesteps: 174000
# Best mean reward: -926.76 - Last mean reward per episode: -939.40
# Num timesteps: 175000
# Best mean reward: -926.76 - Last mean reward per episode: -941.72
# Num timesteps: 176000
# Best mean reward: -926.76 - Last mean reward per episode: -945.76
# Num timesteps: 177000
# Best mean reward: -926.76 - Last mean reward per episode: -948.80
# Num timesteps: 178000
# Best mean reward: -926.76 - Last mean reward per episode: -944.63
# Num timesteps: 179000
# Best mean reward: -926.76 - Last mean reward per episode: -948.02
# Num timesteps: 180000
# Best mean reward: -926.76 - Last mean reward per episode: -938.08
# Num timesteps: 181000
# Best mean reward: -926.76 - Last mean reward per episode: -930.36
# Num timesteps: 182000
# Best mean reward: -926.76 - Last mean reward per episode: -928.58
# Num timesteps: 183000
# Best mean reward: -926.76 - Last mean reward per episode: -922.34
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 184000
# Best mean reward: -922.34 - Last mean reward per episode: -897.71
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 185000
# Best mean reward: -897.71 - Last mean reward per episode: -910.40
# Num timesteps: 186000
# Best mean reward: -897.71 - Last mean reward per episode: -908.49
# Num timesteps: 187000
# Best mean reward: -897.71 - Last mean reward per episode: -916.86
# Num timesteps: 188000
# Best mean reward: -897.71 - Last mean reward per episode: -908.70
# Num timesteps: 189000
# Best mean reward: -897.71 - Last mean reward per episode: -898.89
# Num timesteps: 190000
# Best mean reward: -897.71 - Last mean reward per episode: -885.42
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 191000
# Best mean reward: -885.42 - Last mean reward per episode: -871.88
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 192000
# Best mean reward: -871.88 - Last mean reward per episode: -858.29
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 193000
# Best mean reward: -858.29 - Last mean reward per episode: -833.04
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 194000
# Best mean reward: -833.04 - Last mean reward per episode: -811.57
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 195000
# Best mean reward: -811.57 - Last mean reward per episode: -788.87
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 196000
# Best mean reward: -788.87 - Last mean reward per episode: -775.46
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 197000
# Best mean reward: -775.46 - Last mean reward per episode: -764.11
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 198000
# Best mean reward: -764.11 - Last mean reward per episode: -747.89
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 199000
# Best mean reward: -747.89 - Last mean reward per episode: -733.50
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 200000
# Best mean reward: -733.50 - Last mean reward per episode: -715.56
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 201000
# Best mean reward: -715.56 - Last mean reward per episode: -698.59
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 202000
# Best mean reward: -698.59 - Last mean reward per episode: -690.62
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 203000
# Best mean reward: -690.62 - Last mean reward per episode: -683.70
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 204000
# Best mean reward: -683.70 - Last mean reward per episode: -674.17
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 205000
# Best mean reward: -674.17 - Last mean reward per episode: -641.21
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 206000
# Best mean reward: -641.21 - Last mean reward per episode: -628.79
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 207000
# Best mean reward: -628.79 - Last mean reward per episode: -599.34
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 208000
# Best mean reward: -599.34 - Last mean reward per episode: -587.48
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 209000
# Best mean reward: -587.48 - Last mean reward per episode: -572.08
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 210000
# Best mean reward: -572.08 - Last mean reward per episode: -550.89
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 211000
# Best mean reward: -550.89 - Last mean reward per episode: -537.82
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 212000
# Best mean reward: -537.82 - Last mean reward per episode: -513.37
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 213000
# Best mean reward: -513.37 - Last mean reward per episode: -494.43
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 214000
# Best mean reward: -494.43 - Last mean reward per episode: -481.29
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 215000
# Best mean reward: -481.29 - Last mean reward per episode: -476.11
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 216000
# Best mean reward: -476.11 - Last mean reward per episode: -448.66
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 217000
# Best mean reward: -448.66 - Last mean reward per episode: -421.76
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 218000
# Best mean reward: -421.76 - Last mean reward per episode: -414.76
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 219000
# Best mean reward: -414.76 - Last mean reward per episode: -401.00
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 220000
# Best mean reward: -401.00 - Last mean reward per episode: -394.49
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 221000
# Best mean reward: -394.49 - Last mean reward per episode: -384.92
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 222000
# Best mean reward: -384.92 - Last mean reward per episode: -388.56
# Num timesteps: 223000
# Best mean reward: -384.92 - Last mean reward per episode: -368.86
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 224000
# Best mean reward: -368.86 - Last mean reward per episode: -362.97
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 225000
# Best mean reward: -362.97 - Last mean reward per episode: -353.70
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 226000
# Best mean reward: -353.70 - Last mean reward per episode: -339.79
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 227000
# Best mean reward: -339.79 - Last mean reward per episode: -343.61
# Num timesteps: 228000
# Best mean reward: -339.79 - Last mean reward per episode: -342.99
# Num timesteps: 229000
# Best mean reward: -339.79 - Last mean reward per episode: -334.90
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 230000
# Best mean reward: -334.90 - Last mean reward per episode: -329.94
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 231000
# Best mean reward: -329.94 - Last mean reward per episode: -325.72
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 232000
# Best mean reward: -325.72 - Last mean reward per episode: -324.12
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 233000
# Best mean reward: -324.12 - Last mean reward per episode: -324.80
# Num timesteps: 234000
# Best mean reward: -324.12 - Last mean reward per episode: -327.55
# Num timesteps: 235000
# Best mean reward: -324.12 - Last mean reward per episode: -322.07
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 236000
# Best mean reward: -322.07 - Last mean reward per episode: -326.58
# Num timesteps: 237000
# Best mean reward: -322.07 - Last mean reward per episode: -329.73
# Num timesteps: 238000
# Best mean reward: -322.07 - Last mean reward per episode: -323.59
# Num timesteps: 239000
# Best mean reward: -322.07 - Last mean reward per episode: -315.59
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 240000
# Best mean reward: -315.59 - Last mean reward per episode: -308.70
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 241000
# Best mean reward: -308.70 - Last mean reward per episode: -305.57
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 242000
# Best mean reward: -305.57 - Last mean reward per episode: -283.07
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 243000
# Best mean reward: -283.07 - Last mean reward per episode: -285.94
# Num timesteps: 244000
# Best mean reward: -283.07 - Last mean reward per episode: -279.38
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 245000
# Best mean reward: -279.38 - Last mean reward per episode: -285.58
# Num timesteps: 246000
# Best mean reward: -279.38 - Last mean reward per episode: -281.63
# Num timesteps: 247000
# Best mean reward: -279.38 - Last mean reward per episode: -277.34
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 248000
# Best mean reward: -277.34 - Last mean reward per episode: -266.57
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 249000
# Best mean reward: -266.57 - Last mean reward per episode: -265.68
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 250000
# Best mean reward: -265.68 - Last mean reward per episode: -268.82
# Num timesteps: 251000
# Best mean reward: -265.68 - Last mean reward per episode: -257.87
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 252000
# Best mean reward: -257.87 - Last mean reward per episode: -252.73
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 253000
# Best mean reward: -252.73 - Last mean reward per episode: -255.59
# Num timesteps: 254000
# Best mean reward: -252.73 - Last mean reward per episode: -242.31
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 255000
# Best mean reward: -242.31 - Last mean reward per episode: -237.14
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 256000
# Best mean reward: -237.14 - Last mean reward per episode: -235.72
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 257000
# Best mean reward: -235.72 - Last mean reward per episode: -233.88
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 258000
# Best mean reward: -233.88 - Last mean reward per episode: -225.92
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 259000
# Best mean reward: -225.92 - Last mean reward per episode: -226.30
# Num timesteps: 260000
# Best mean reward: -225.92 - Last mean reward per episode: -219.45
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 261000
# Best mean reward: -219.45 - Last mean reward per episode: -216.37
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 262000
# Best mean reward: -216.37 - Last mean reward per episode: -215.09
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 263000
# Best mean reward: -215.09 - Last mean reward per episode: -206.99
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 264000
# Best mean reward: -206.99 - Last mean reward per episode: -207.67
# Num timesteps: 265000
# Best mean reward: -206.99 - Last mean reward per episode: -202.82
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 266000
# Best mean reward: -202.82 - Last mean reward per episode: -200.83
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 267000
# Best mean reward: -200.83 - Last mean reward per episode: -202.22
# Num timesteps: 268000
# Best mean reward: -200.83 - Last mean reward per episode: -203.26
# Num timesteps: 269000
# Best mean reward: -200.83 - Last mean reward per episode: -210.63
# Num timesteps: 270000
# Best mean reward: -200.83 - Last mean reward per episode: -205.20
# Num timesteps: 271000
# Best mean reward: -200.83 - Last mean reward per episode: -208.11
# Num timesteps: 272000
# Best mean reward: -200.83 - Last mean reward per episode: -206.94
# Num timesteps: 273000
# Best mean reward: -200.83 - Last mean reward per episode: -201.99
# Num timesteps: 274000
# Best mean reward: -200.83 - Last mean reward per episode: -207.30
# Num timesteps: 275000
# Best mean reward: -200.83 - Last mean reward per episode: -205.02
# Num timesteps: 276000
# Best mean reward: -200.83 - Last mean reward per episode: -204.50
# Num timesteps: 277000
# Best mean reward: -200.83 - Last mean reward per episode: -209.04
# Num timesteps: 278000
# Best mean reward: -200.83 - Last mean reward per episode: -214.75
# Num timesteps: 279000
# Best mean reward: -200.83 - Last mean reward per episode: -210.63
# Num timesteps: 280000
# Best mean reward: -200.83 - Last mean reward per episode: -215.80
# Num timesteps: 281000
# Best mean reward: -200.83 - Last mean reward per episode: -212.64
# Num timesteps: 282000
# Best mean reward: -200.83 - Last mean reward per episode: -212.62
# Num timesteps: 283000
# Best mean reward: -200.83 - Last mean reward per episode: -214.74
# Num timesteps: 284000
# Best mean reward: -200.83 - Last mean reward per episode: -214.75
# Num timesteps: 285000
# Best mean reward: -200.83 - Last mean reward per episode: -218.74
# Num timesteps: 286000
# Best mean reward: -200.83 - Last mean reward per episode: -224.55
# Num timesteps: 287000
# Best mean reward: -200.83 - Last mean reward per episode: -227.57
# Num timesteps: 288000
# Best mean reward: -200.83 - Last mean reward per episode: -219.50
# Num timesteps: 289000
# Best mean reward: -200.83 - Last mean reward per episode: -209.44
# Num timesteps: 290000
# Best mean reward: -200.83 - Last mean reward per episode: -209.47
# Num timesteps: 291000
# Best mean reward: -200.83 - Last mean reward per episode: -209.68
# Num timesteps: 292000
# Best mean reward: -200.83 - Last mean reward per episode: -211.01
# Num timesteps: 293000
# Best mean reward: -200.83 - Last mean reward per episode: -213.53
# Num timesteps: 294000
# Best mean reward: -200.83 - Last mean reward per episode: -217.23
# Num timesteps: 295000
# Best mean reward: -200.83 - Last mean reward per episode: -224.68
# Num timesteps: 296000
# Best mean reward: -200.83 - Last mean reward per episode: -220.65
# Num timesteps: 297000
# Best mean reward: -200.83 - Last mean reward per episode: -212.74
# Num timesteps: 298000
# Best mean reward: -200.83 - Last mean reward per episode: -211.28
# Num timesteps: 299000
# Best mean reward: -200.83 - Last mean reward per episode: -215.22
# Num timesteps: 300000
# Best mean reward: -200.83 - Last mean reward per episode: -214.29
# Num timesteps: 301000
# Best mean reward: -200.83 - Last mean reward per episode: -213.96
# Num timesteps: 302000
# Best mean reward: -200.83 - Last mean reward per episode: -217.09
# Num timesteps: 303000
# Best mean reward: -200.83 - Last mean reward per episode: -211.83
# Num timesteps: 304000
# Best mean reward: -200.83 - Last mean reward per episode: -209.59
# Num timesteps: 305000
# Best mean reward: -200.83 - Last mean reward per episode: -204.14
# Num timesteps: 306000
# Best mean reward: -200.83 - Last mean reward per episode: -201.23
# Num timesteps: 307000
# Best mean reward: -200.83 - Last mean reward per episode: -197.82
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 308000
# Best mean reward: -197.82 - Last mean reward per episode: -200.89
# Num timesteps: 309000
# Best mean reward: -197.82 - Last mean reward per episode: -206.79
# Num timesteps: 310000
# Best mean reward: -197.82 - Last mean reward per episode: -206.77
# Num timesteps: 311000
# Best mean reward: -197.82 - Last mean reward per episode: -203.85
# Num timesteps: 312000
# Best mean reward: -197.82 - Last mean reward per episode: -203.57
# Num timesteps: 313000
# Best mean reward: -197.82 - Last mean reward per episode: -197.15
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 314000
# Best mean reward: -197.15 - Last mean reward per episode: -194.19
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 315000
# Best mean reward: -194.19 - Last mean reward per episode: -191.80
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 316000
# Best mean reward: -191.80 - Last mean reward per episode: -189.33
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 317000
# Best mean reward: -189.33 - Last mean reward per episode: -184.58
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 318000
# Best mean reward: -184.58 - Last mean reward per episode: -183.68
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 319000
# Best mean reward: -183.68 - Last mean reward per episode: -182.14
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 320000
# Best mean reward: -182.14 - Last mean reward per episode: -179.15
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 321000
# Best mean reward: -179.15 - Last mean reward per episode: -176.72
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 322000
# Best mean reward: -176.72 - Last mean reward per episode: -173.47
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 323000
# Best mean reward: -173.47 - Last mean reward per episode: -178.40
# Num timesteps: 324000
# Best mean reward: -173.47 - Last mean reward per episode: -176.88
# Num timesteps: 325000
# Best mean reward: -173.47 - Last mean reward per episode: -181.74
# Num timesteps: 326000
# Best mean reward: -173.47 - Last mean reward per episode: -188.19
# Num timesteps: 327000
# Best mean reward: -173.47 - Last mean reward per episode: -184.26
# Num timesteps: 328000
# Best mean reward: -173.47 - Last mean reward per episode: -177.51
# Num timesteps: 329000
# Best mean reward: -173.47 - Last mean reward per episode: -180.09
# Num timesteps: 330000
# Best mean reward: -173.47 - Last mean reward per episode: -182.68
# Num timesteps: 331000
# Best mean reward: -173.47 - Last mean reward per episode: -182.67
# Num timesteps: 332000
# Best mean reward: -173.47 - Last mean reward per episode: -181.43
# Num timesteps: 333000
# Best mean reward: -173.47 - Last mean reward per episode: -185.23
# Num timesteps: 334000
# Best mean reward: -173.47 - Last mean reward per episode: -183.67
# Num timesteps: 335000
# Best mean reward: -173.47 - Last mean reward per episode: -186.28
# Num timesteps: 336000
# Best mean reward: -173.47 - Last mean reward per episode: -192.71
# Num timesteps: 337000
# Best mean reward: -173.47 - Last mean reward per episode: -192.59
# Num timesteps: 338000
# Best mean reward: -173.47 - Last mean reward per episode: -210.50
# Num timesteps: 339000
# Best mean reward: -173.47 - Last mean reward per episode: -211.51
# Num timesteps: 340000
# Best mean reward: -173.47 - Last mean reward per episode: -217.56
# Num timesteps: 341000
# Best mean reward: -173.47 - Last mean reward per episode: -225.10
# Num timesteps: 342000
# Best mean reward: -173.47 - Last mean reward per episode: -225.07
# Num timesteps: 343000
# Best mean reward: -173.47 - Last mean reward per episode: -221.82
# Num timesteps: 344000
# Best mean reward: -173.47 - Last mean reward per episode: -223.24
# Num timesteps: 345000
# Best mean reward: -173.47 - Last mean reward per episode: -220.58
# Num timesteps: 346000
# Best mean reward: -173.47 - Last mean reward per episode: -210.84
# Num timesteps: 347000
# Best mean reward: -173.47 - Last mean reward per episode: -210.71
# Num timesteps: 348000
# Best mean reward: -173.47 - Last mean reward per episode: -213.13
# Num timesteps: 349000
# Best mean reward: -173.47 - Last mean reward per episode: -202.78
# Num timesteps: 350000
# Best mean reward: -173.47 - Last mean reward per episode: -201.56
# Num timesteps: 351000
# Best mean reward: -173.47 - Last mean reward per episode: -201.63
# Num timesteps: 352000
# Best mean reward: -173.47 - Last mean reward per episode: -204.47
# Num timesteps: 353000
# Best mean reward: -173.47 - Last mean reward per episode: -212.94
# Num timesteps: 354000
# Best mean reward: -173.47 - Last mean reward per episode: -222.43
# Num timesteps: 355000
# Best mean reward: -173.47 - Last mean reward per episode: -214.18
# Num timesteps: 356000
# Best mean reward: -173.47 - Last mean reward per episode: -213.95
# Num timesteps: 357000
# Best mean reward: -173.47 - Last mean reward per episode: -217.65
# Num timesteps: 358000
# Best mean reward: -173.47 - Last mean reward per episode: -200.22
# Num timesteps: 359000
# Best mean reward: -173.47 - Last mean reward per episode: -200.32
# Num timesteps: 360000
# Best mean reward: -173.47 - Last mean reward per episode: -195.61
# Num timesteps: 361000
# Best mean reward: -173.47 - Last mean reward per episode: -191.60
# Num timesteps: 362000
# Best mean reward: -173.47 - Last mean reward per episode: -193.08
# Num timesteps: 363000
# Best mean reward: -173.47 - Last mean reward per episode: -191.51
# Num timesteps: 364000
# Best mean reward: -173.47 - Last mean reward per episode: -191.81
# Num timesteps: 365000
# Best mean reward: -173.47 - Last mean reward per episode: -189.48
# Num timesteps: 366000
# Best mean reward: -173.47 - Last mean reward per episode: -190.13
# Num timesteps: 367000
# Best mean reward: -173.47 - Last mean reward per episode: -188.62
# Num timesteps: 368000
# Best mean reward: -173.47 - Last mean reward per episode: -190.10
# Num timesteps: 369000
# Best mean reward: -173.47 - Last mean reward per episode: -190.05
# Num timesteps: 370000
# Best mean reward: -173.47 - Last mean reward per episode: -192.34
# Num timesteps: 371000
# Best mean reward: -173.47 - Last mean reward per episode: -188.27
# Num timesteps: 372000
# Best mean reward: -173.47 - Last mean reward per episode: -192.06
# Num timesteps: 373000
# Best mean reward: -173.47 - Last mean reward per episode: -197.93
# Num timesteps: 374000
# Best mean reward: -173.47 - Last mean reward per episode: -187.81
# Num timesteps: 375000
# Best mean reward: -173.47 - Last mean reward per episode: -196.63
# Num timesteps: 376000
# Best mean reward: -173.47 - Last mean reward per episode: -202.05
# Num timesteps: 377000
# Best mean reward: -173.47 - Last mean reward per episode: -205.47
# Num timesteps: 378000
# Best mean reward: -173.47 - Last mean reward per episode: -201.75
# Num timesteps: 379000
# Best mean reward: -173.47 - Last mean reward per episode: -207.50
# Num timesteps: 380000
# Best mean reward: -173.47 - Last mean reward per episode: -210.37
# Num timesteps: 381000
# Best mean reward: -173.47 - Last mean reward per episode: -218.74
# Num timesteps: 382000
# Best mean reward: -173.47 - Last mean reward per episode: -226.85
# Num timesteps: 383000
# Best mean reward: -173.47 - Last mean reward per episode: -239.04
# Num timesteps: 384000
# Best mean reward: -173.47 - Last mean reward per episode: -238.61
# Num timesteps: 385000
# Best mean reward: -173.47 - Last mean reward per episode: -251.14
# Num timesteps: 386000
# Best mean reward: -173.47 - Last mean reward per episode: -258.28
# Num timesteps: 387000
# Best mean reward: -173.47 - Last mean reward per episode: -277.53
# Num timesteps: 388000
# Best mean reward: -173.47 - Last mean reward per episode: -297.00
# Num timesteps: 389000
# Best mean reward: -173.47 - Last mean reward per episode: -319.63
# Num timesteps: 390000
# Best mean reward: -173.47 - Last mean reward per episode: -326.81
# Num timesteps: 391000
# Best mean reward: -173.47 - Last mean reward per episode: -342.54
# Num timesteps: 392000
# Best mean reward: -173.47 - Last mean reward per episode: -346.87
# Num timesteps: 393000
# Best mean reward: -173.47 - Last mean reward per episode: -363.45
# Num timesteps: 394000
# Best mean reward: -173.47 - Last mean reward per episode: -366.55
# Num timesteps: 395000
# Best mean reward: -173.47 - Last mean reward per episode: -358.92
# Num timesteps: 396000
# Best mean reward: -173.47 - Last mean reward per episode: -370.20
# Num timesteps: 397000
# Best mean reward: -173.47 - Last mean reward per episode: -364.17
# Num timesteps: 398000
# Best mean reward: -173.47 - Last mean reward per episode: -377.32
# Num timesteps: 399000
# Best mean reward: -173.47 - Last mean reward per episode: -397.06
# Num timesteps: 400000
# Best mean reward: -173.47 - Last mean reward per episode: -408.47
# Num timesteps: 401000
# Best mean reward: -173.47 - Last mean reward per episode: -400.05
# Num timesteps: 402000
# Best mean reward: -173.47 - Last mean reward per episode: -402.45
# Num timesteps: 403000
# Best mean reward: -173.47 - Last mean reward per episode: -388.95
# Num timesteps: 404000
# Best mean reward: -173.47 - Last mean reward per episode: -396.27
# Num timesteps: 405000
# Best mean reward: -173.47 - Last mean reward per episode: -393.86
# Num timesteps: 406000
# Best mean reward: -173.47 - Last mean reward per episode: -397.32
# Num timesteps: 407000
# Best mean reward: -173.47 - Last mean reward per episode: -382.89
# Num timesteps: 408000
# Best mean reward: -173.47 - Last mean reward per episode: -373.65
# Num timesteps: 409000
# Best mean reward: -173.47 - Last mean reward per episode: -355.32
# Num timesteps: 410000
# Best mean reward: -173.47 - Last mean reward per episode: -355.58
# Num timesteps: 411000
# Best mean reward: -173.47 - Last mean reward per episode: -343.60
# Num timesteps: 412000
# Best mean reward: -173.47 - Last mean reward per episode: -337.76
# Num timesteps: 413000
# Best mean reward: -173.47 - Last mean reward per episode: -311.69
# Num timesteps: 414000
# Best mean reward: -173.47 - Last mean reward per episode: -311.98
# Num timesteps: 415000
# Best mean reward: -173.47 - Last mean reward per episode: -313.33
# Num timesteps: 416000
# Best mean reward: -173.47 - Last mean reward per episode: -292.70
# Num timesteps: 417000
# Best mean reward: -173.47 - Last mean reward per episode: -296.59
# Num timesteps: 418000
# Best mean reward: -173.47 - Last mean reward per episode: -286.07
# Num timesteps: 419000
# Best mean reward: -173.47 - Last mean reward per episode: -259.97
# Num timesteps: 420000
# Best mean reward: -173.47 - Last mean reward per episode: -249.00
# Num timesteps: 421000
# Best mean reward: -173.47 - Last mean reward per episode: -249.03
# Num timesteps: 422000
# Best mean reward: -173.47 - Last mean reward per episode: -238.58
# Num timesteps: 423000
# Best mean reward: -173.47 - Last mean reward per episode: -247.71
# Num timesteps: 424000
# Best mean reward: -173.47 - Last mean reward per episode: -240.27
# Num timesteps: 425000
# Best mean reward: -173.47 - Last mean reward per episode: -231.60
# Num timesteps: 426000
# Best mean reward: -173.47 - Last mean reward per episode: -220.28
# Num timesteps: 427000
# Best mean reward: -173.47 - Last mean reward per episode: -218.10
# Num timesteps: 428000
# Best mean reward: -173.47 - Last mean reward per episode: -207.83
# Num timesteps: 429000
# Best mean reward: -173.47 - Last mean reward per episode: -205.87
# Num timesteps: 430000
# Best mean reward: -173.47 - Last mean reward per episode: -195.87
# Num timesteps: 431000
# Best mean reward: -173.47 - Last mean reward per episode: -195.83
# Num timesteps: 432000
# Best mean reward: -173.47 - Last mean reward per episode: -192.04
# Num timesteps: 433000
# Best mean reward: -173.47 - Last mean reward per episode: -187.30
# Num timesteps: 434000
# Best mean reward: -173.47 - Last mean reward per episode: -183.59
# Num timesteps: 435000
# Best mean reward: -173.47 - Last mean reward per episode: -184.90
# Num timesteps: 436000
# Best mean reward: -173.47 - Last mean reward per episode: -192.53
# Num timesteps: 437000
# Best mean reward: -173.47 - Last mean reward per episode: -196.60
# Num timesteps: 438000
# Best mean reward: -173.47 - Last mean reward per episode: -196.58
# Num timesteps: 439000
# Best mean reward: -173.47 - Last mean reward per episode: -194.92
# Num timesteps: 440000
# Best mean reward: -173.47 - Last mean reward per episode: -191.36
# Num timesteps: 441000
# Best mean reward: -173.47 - Last mean reward per episode: -186.60
# Num timesteps: 442000
# Best mean reward: -173.47 - Last mean reward per episode: -182.78
# Num timesteps: 443000
# Best mean reward: -173.47 - Last mean reward per episode: -173.82
# Num timesteps: 444000
# Best mean reward: -173.47 - Last mean reward per episode: -172.86
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 445000
# Best mean reward: -172.86 - Last mean reward per episode: -175.84
# Num timesteps: 446000
# Best mean reward: -172.86 - Last mean reward per episode: -178.86
# Num timesteps: 447000
# Best mean reward: -172.86 - Last mean reward per episode: -180.02
# Num timesteps: 448000
# Best mean reward: -172.86 - Last mean reward per episode: -176.10
# Num timesteps: 449000
# Best mean reward: -172.86 - Last mean reward per episode: -172.69
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 450000
# Best mean reward: -172.69 - Last mean reward per episode: -172.83
# Num timesteps: 451000
# Best mean reward: -172.69 - Last mean reward per episode: -179.44
# Num timesteps: 452000
# Best mean reward: -172.69 - Last mean reward per episode: -179.18
# Num timesteps: 453000
# Best mean reward: -172.69 - Last mean reward per episode: -183.07
# Num timesteps: 454000
# Best mean reward: -172.69 - Last mean reward per episode: -180.71
# Num timesteps: 455000
# Best mean reward: -172.69 - Last mean reward per episode: -178.32
# Num timesteps: 456000
# Best mean reward: -172.69 - Last mean reward per episode: -173.88
# Num timesteps: 457000
# Best mean reward: -172.69 - Last mean reward per episode: -168.89
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 458000
# Best mean reward: -168.89 - Last mean reward per episode: -171.59
# Num timesteps: 459000
# Best mean reward: -168.89 - Last mean reward per episode: -170.04
# Num timesteps: 460000
# Best mean reward: -168.89 - Last mean reward per episode: -165.05
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 461000
# Best mean reward: -165.05 - Last mean reward per episode: -171.27
# Num timesteps: 462000
# Best mean reward: -165.05 - Last mean reward per episode: -167.22
# Num timesteps: 463000
# Best mean reward: -165.05 - Last mean reward per episode: -170.62
# Num timesteps: 464000
# Best mean reward: -165.05 - Last mean reward per episode: -171.84
# Num timesteps: 465000
# Best mean reward: -165.05 - Last mean reward per episode: -168.21
# Num timesteps: 466000
# Best mean reward: -165.05 - Last mean reward per episode: -166.27
# Num timesteps: 467000
# Best mean reward: -165.05 - Last mean reward per episode: -163.80
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 468000
# Best mean reward: -163.80 - Last mean reward per episode: -171.27
# Num timesteps: 469000
# Best mean reward: -163.80 - Last mean reward per episode: -174.50
# Num timesteps: 470000
# Best mean reward: -163.80 - Last mean reward per episode: -177.12
# Num timesteps: 471000
# Best mean reward: -163.80 - Last mean reward per episode: -171.71
# Num timesteps: 472000
# Best mean reward: -163.80 - Last mean reward per episode: -172.78
# Num timesteps: 473000
# Best mean reward: -163.80 - Last mean reward per episode: -164.92
# Num timesteps: 474000
# Best mean reward: -163.80 - Last mean reward per episode: -167.39
# Num timesteps: 475000
# Best mean reward: -163.80 - Last mean reward per episode: -170.10
# Num timesteps: 476000
# Best mean reward: -163.80 - Last mean reward per episode: -166.99
# Num timesteps: 477000
# Best mean reward: -163.80 - Last mean reward per episode: -165.39
# Num timesteps: 478000
# Best mean reward: -163.80 - Last mean reward per episode: -161.93
# Saving new best model to C:/Users/Lenovo/Desktop/Python/Reinforcement Learning/5. PPO/SB3/tmp/best_model.zip
# Num timesteps: 479000
# Best mean reward: -161.93 - Last mean reward per episode: -163.52
# Num timesteps: 480000
# Best mean reward: -161.93 - Last mean reward per episode: -173.83
# Num timesteps: 481000
# Best mean reward: -161.93 - Last mean reward per episode: -172.69
# Num timesteps: 482000
# Best mean reward: -161.93 - Last mean reward per episode: -175.06
# Num timesteps: 483000
# Best mean reward: -161.93 - Last mean reward per episode: -174.66
# Num timesteps: 484000
# Best mean reward: -161.93 - Last mean reward per episode: -177.83
# Num timesteps: 485000
# Best mean reward: -161.93 - Last mean reward per episode: -187.18
# Num timesteps: 486000
# Best mean reward: -161.93 - Last mean reward per episode: -187.19
# Num timesteps: 487000
# Best mean reward: -161.93 - Last mean reward per episode: -185.84
# Num timesteps: 488000
# Best mean reward: -161.93 - Last mean reward per episode: -182.19
# Num timesteps: 489000
# Best mean reward: -161.93 - Last mean reward per episode: -182.08
# Num timesteps: 490000
# Best mean reward: -161.93 - Last mean reward per episode: -180.93
# Num timesteps: 491000
# Best mean reward: -161.93 - Last mean reward per episode: -178.49
# Num timesteps: 492000
# Best mean reward: -161.93 - Last mean reward per episode: -178.74
# Num timesteps: 493000
# Best mean reward: -161.93 - Last mean reward per episode: -188.69
# Num timesteps: 494000
# Best mean reward: -161.93 - Last mean reward per episode: -186.18
# Num timesteps: 495000
# Best mean reward: -161.93 - Last mean reward per episode: -184.90
# Num timesteps: 496000
# Best mean reward: -161.93 - Last mean reward per episode: -183.78
# Num timesteps: 497000
# Best mean reward: -161.93 - Last mean reward per episode: -186.28
# Num timesteps: 498000
# Best mean reward: -161.93 - Last mean reward per episode: -185.56
# Num timesteps: 499000
# Best mean reward: -161.93 - Last mean reward per episode: -184.10
# Num timesteps: 500000
# Best mean reward: -161.93 - Last mean reward per episode: -181.42
# Num timesteps: 501000
# Best mean reward: -161.93 - Last mean reward per episode: -181.31

# %%
# Plotting

def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, 'valid')


def plot_results(log_folder, title='Learning Curve'):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    
    x, y = ts2xy(load_results(log_folder), 'timesteps')

    y_mean = moving_average(y, window=50)
    # Truncate x
    x_mean = x[len(x) - len(y_mean):]

    fig = plt.figure(title)
    plt.plot(x, y, alpha=0.4, label="Rewards")
    plt.plot(x_mean, y_mean, label="Mean rewards - wd:50")
    plt.xlabel('Number of Timesteps')
    plt.ylabel('Rewards')
    plt.title(title)
    plt.legend(loc="best")
    plt.show()


plot_results(log_dir)

# %%
# Test 

scores = []
for i in range(100):
    obs = env.reset()
    score = 0
    done = False
    
    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        score += reward
    
    scores.append(score)

np.mean(scores)
# Out:
# -166.50520149098003
